# %%
#Import dependencies
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import numpy as np
import string
import operator
from sklearn.feature_extraction.text import CountVectorizer
import pickle

import nltk
from nltk.corpus import stopwords
nltk.download('stopwords')
from nltk.tokenize import word_tokenize
# Out:
# [nltk_data] Downloading package stopwords to
# [nltk_data]     C:\Users\kledesma\AppData\Roaming\nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!

# %%
df = pd.read_csv('../../yelp-dataset/yelp_reviews.csv')

# %%
#Extracting the fields I want
df2 = df[['name', 'city', 'state', 'stars', 'review_stars', 'text', 'date']]

# %%
print(df2.head())

print(df2.describe())

print(min(df2['date']))
print(max(df2['date']))
print(df2.info())
# Out:
#                   name       city state  stars  review_stars  \
# 0  The Empanadas House  Champaign    IL    4.5             5
# 1  The Empanadas House  Champaign    IL    4.5             5
# 2  The Empanadas House  Champaign    IL    4.5             2
# 3  The Empanadas House  Champaign    IL    4.5             5
# 4  The Empanadas House  Champaign    IL    4.5             5
#
#                                                 text                 date
# 0  I love the empanadas from the Empanadas House!...  2013-04-11 18:36:15
# 1  I ordered feta cheese and spinach empanadas an...  2017-09-21 17:45:53
# 2  I went to the place on Green St today. I went ...  2014-10-07 01:07:00
# 3  These empanadas are excellent- we are Argentin...  2013-07-10 18:26:33
# 4  These empanadas are HUGE and in my opinion bet...  2019-05-07 03:12:10
#               stars  review_stars
# count  4.222976e+06  4.222976e+06
# mean   3.761974e+00  3.760848e+00
# std    6.231684e-01  1.392453e+00
# min    1.000000e+00  1.000000e+00
# 25%    3.500000e+00  3.000000e+00
# 50%    4.000000e+00  4.000000e+00
# 75%    4.000000e+00  5.000000e+00
# max    5.000000e+00  5.000000e+00
# 2004-10-19 09:07:15
# 2019-12-13 15:50:49
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4222976 entries, 0 to 4222975
# Data columns (total 7 columns):
#  #   Column        Dtype
# ---  ------        -----
#  0   name          object
#  1   city          object
#  2   state         object
#  3   stars         float64
#  4   review_stars  int64
#  5   text          object
#  6   date          object
# dtypes: float64(1), int64(1), object(5)
# memory usage: 225.5+ MB
# None

# %%
#Looking at the rating distribution
sns.countplot(x="review_stars", data = df2)

# %%
#Extracting only reviews that are 1,2,4, or 5 stars
df5 = df2[(df2['review_stars'] == 1) | (df2['review_stars'] == 2) | (df2['review_stars'] == 4) | (df2['review_stars'] == 5)]
df5
# Out:
#                              name       city state  stars  review_stars  \
# 0             The Empanadas House  Champaign    IL    4.5             5
# 1             The Empanadas House  Champaign    IL    4.5             5
# 2             The Empanadas House  Champaign    IL    4.5             2
# 3             The Empanadas House  Champaign    IL    4.5             5
# 4             The Empanadas House  Champaign    IL    4.5             5
# ...                           ...        ...   ...    ...           ...
# 4222968  Yao Fine Chinese Cuisine    Gilbert    AZ    4.0             5
# 4222969  Yao Fine Chinese Cuisine    Gilbert    AZ    4.0             1
# 4222971  Yao Fine Chinese Cuisine    Gilbert    AZ    4.0             5
# 4222972                   Hooters    Phoenix    AZ    2.0             1
# 4222973                   Hooters    Phoenix    AZ    2.0             1
#
#                                                       text  \
# 0        I love the empanadas from the Empanadas House!...
# 1        I ordered feta cheese and spinach empanadas an...
# 2        I went to the place on Green St today. I went ...
# 3        These empanadas are excellent- we are Argentin...
# 4        These empanadas are HUGE and in my opinion bet...
# ...                                                    ...
# 4222968  It had been awhile since we last dined here.  ...
# 4222969  Seat yourself type of place, ordered fried won...
# 4222971  Came for dinner based on reviews. Service was ...
# 4222972  I hate to give a one star, but this place need...
# 4222973  I LOVE HOOTERS! When I came to this particular...
#
#                         date
# 0        2013-04-11 18:36:15
# 1        2017-09-21 17:45:53
# 2        2014-10-07 01:07:00
# 3        2013-07-10 18:26:33
# 4        2019-05-07 03:12:10
# ...                      ...
# 4222968  2019-11-24 07:41:46
# 4222969  2019-11-27 01:53:07
# 4222971  2019-10-27 02:47:25
# 4222972  2019-01-19 03:05:09
# 4222973  2017-06-08 17:59:16
#
# [3706704 rows x 7 columns]

# %%
#Creating sentiment value
df5['sentiment'] = np.where(df5['review_stars'] < 3, 'Negative', 'Positive')
df5.head()
# Out:
# C:\Users\kledesma\Anaconda3\lib\site-packages\ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#                   name       city state  stars  review_stars  \
# 0  The Empanadas House  Champaign    IL    4.5             5
# 1  The Empanadas House  Champaign    IL    4.5             5
# 2  The Empanadas House  Champaign    IL    4.5             2
# 3  The Empanadas House  Champaign    IL    4.5             5
# 4  The Empanadas House  Champaign    IL    4.5             5
#
#                                                 text                 date  \
# 0  I love the empanadas from the Empanadas House!...  2013-04-11 18:36:15
# 1  I ordered feta cheese and spinach empanadas an...  2017-09-21 17:45:53
# 2  I went to the place on Green St today. I went ...  2014-10-07 01:07:00
# 3  These empanadas are excellent- we are Argentin...  2013-07-10 18:26:33
# 4  These empanadas are HUGE and in my opinion bet...  2019-05-07 03:12:10
#
#   sentiment
# 0  Positive
# 1  Positive
# 2  Negative
# 3  Positive
# 4  Positive

# %%
#Taking large sample to create the model
df6 = df5[:20000]
df6 = df6.reset_index()

#creating x, y to be used later for ML model
x = df6['text']
y = df6['sentiment']


df6
# Out:
#        index                 name       city state  stars  review_stars  \
# 0          0  The Empanadas House  Champaign    IL    4.5             5
# 1          1  The Empanadas House  Champaign    IL    4.5             5
# 2          2  The Empanadas House  Champaign    IL    4.5             2
# 3          3  The Empanadas House  Champaign    IL    4.5             5
# 4          4  The Empanadas House  Champaign    IL    4.5             5
# ...      ...                  ...        ...   ...    ...           ...
# 19995  22687   Korean Grill House    Toronto    ON    3.0             4
# 19996  22690   Korean Grill House    Toronto    ON    3.0             5
# 19997  22691   Korean Grill House    Toronto    ON    3.0             4
# 19998  22692   Korean Grill House    Toronto    ON    3.0             1
# 19999  22693   Korean Grill House    Toronto    ON    3.0             1
#
#                                                     text                 date  \
# 0      I love the empanadas from the Empanadas House!...  2013-04-11 18:36:15
# 1      I ordered feta cheese and spinach empanadas an...  2017-09-21 17:45:53
# 2      I went to the place on Green St today. I went ...  2014-10-07 01:07:00
# 3      These empanadas are excellent- we are Argentin...  2013-07-10 18:26:33
# 4      These empanadas are HUGE and in my opinion bet...  2019-05-07 03:12:10
# ...                                                  ...                  ...
# 19995  Had to eat here again!\n$ 16 all you can eat K...  2013-04-18 13:40:47
# 19996  This is the best place for Korean grilled food...  2012-03-15 23:04:36
# 19997  Been to this restaurant a few times over the l...  2017-07-02 18:30:18
# 19998  Korean Grill House \nCame here on a Monday. It...  2014-04-29 02:08:08
# 19999  Maybe we're a bit spoiled from Picnic Garden o...  2013-03-24 07:52:34
#
#       sentiment
# 0      Positive
# 1      Positive
# 2      Negative
# 3      Positive
# 4      Positive
# ...         ...
# 19995  Positive
# 19996  Positive
# 19997  Positive
# 19998  Negative
# 19999  Negative
#
# [20000 rows x 9 columns]

# %%
#Creating text analyzer
def text_process(text):

    nopunc = [char for char in text if char not in string.punctuation]
    nopunc = ''.join(nopunc)
    
    return [word for word in nopunc.split() if word.lower() not in stopwords.words('english')]


print(stopwords.words('english'))

sample_text = "Hey there! This is a sample review, which happens to contain punctuations."
processed_text = text_process(sample_text)


print(f"This is the original text: {sample_text}")
print(f"This is the converted text: {processed_text}")

# %%
#Creating the countvectorizor, transforming the data for the model
from sklearn.feature_extraction.text import CountVectorizer

cv = CountVectorizer(analyzer=text_process)   
cv_fit=cv.fit_transform(df6['text'])

#converting into a sparse matrix (will have to repeat for web-scraped data)
X = cv.transform(x)


#Saving vectorizer
pickle.dump(cv, open("vectorizer.pickle", "wb"))

# %%
#Loading Vectorizor
loaded_vectorizor = pickle.load(open("vectorizer.pickle", 'rb'))

# %%
#Splitting data to create model
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=101)

#importing specific ML model, fitting model
from sklearn.naive_bayes import MultinomialNB
model = MultinomialNB()
model.fit(X_train, y_train)

#testing model
predictions = model.predict(X_test)

#Printing results of model
from sklearn.metrics import confusion_matrix, classification_report
print(confusion_matrix(y_test, predictions))
print('\n')
print(classification_report(y_test, predictions))

#Saving the model
import pickle
pickle.dump(model, open("model.pickle", 'wb'))
# Out:
# [[1205  239]
#  [ 167 4389]]
#
#
#               precision    recall  f1-score   support
#
#     Negative       0.88      0.83      0.86      1444
#     Positive       0.95      0.96      0.96      4556
#
#     accuracy                           0.93      6000
#    macro avg       0.91      0.90      0.91      6000
# weighted avg       0.93      0.93      0.93      6000

# %%
#Loading the model
loaded_model = pickle.load(open("model.pickle", 'rb'))

result_val = loaded_model.score(X_train, y_train)
result_test = loaded_model.score(X_test, y_test)


#printing results
print(result_val)
print(result_test)


#Loading Vectorizor
loaded_vectorizor = pickle.load(open("vectorizer.pickle", 'rb'))
# Out:
# 0.9604285714285714
# 0.9323333333333333

# %%
#Keep running to see different samples
from random import randint
n = randint(1, len(df6)-1)
#n = 3291
print(f"Randomizer ID: {n}\n---------------------------------")

#Pulling up info for sample review
sample_review = df6['text'][n]
actual = df6['review_stars'][n]
if actual == 1 | 2:
    actual = 'Negative'
else: actual = 'Positive'
restaurant = df6['name'][n]


review_transformed = cv.transform([sample_review])
      
      
#generating predicted score value      
predicted = loaded_model.predict(review_transformed)[0]

if predicted == actual:
    status = 'Success'
else: status = 'Fail'
        
print(f"Restaurant Name: {restaurant}")
print(f"Review Text: {sample_review} \n")
print(f"ML Predicted Yelp Review Score: {predicted}")
print(f"Actual Yelp Review Score: {actual}\n")
print(f"Status: {status}")
# Out:
# Randomizer ID: 6849
# ---------------------------------
# Restaurant Name: Garcia's
# Review Text: Tampico chicken was recommended by the waitress and did not disappoint.  The food was fresh, nicely presented, and had excellent flavor.  Visited on a Thursday night at 5:30 p.m.  The place was quiet and the service great.  Customers started arriving in mass around 6.  The portions were generous and although the interior was more bar-like than Mexican, it didn't disappointment.  The neighborhood was somewhat "shady", but the food made up for it.  Will go again.
#
# ML Predicted Yelp Review Score: Positive
# Actual Yelp Review Score: Positive
#
# Status: Success

# %%
#Bringing in web scraping code
web_scrapedf = pd.read_csv("../web_scrape_csv")
results = web_scrapedf
print(web_scrapedf.head())
# Out:
#                                              Reviews
# 0  OH MY GOD i think i talk about hattie b's ever...
# 1  Hattie B's Moreland Ave location gets 4.5 star...
# 2  This chicken is everything !! Amazingly crisp ...
# 3  Hattie B's has perfected spicy chicken. This w...
# 4  So....I'm not really sure what all of the hype...

# %%
#Looping through the web-scraped reviews to have the ML make predictions on each review
for label, row in results.iterrows():
    result = []
    text = row['Reviews']
    #print(text)
    text_transform = loaded_vectorizor.transform([text])
    #print(text_transform)[0]
    ml_prediction = loaded_model.predict(text_transform)[0]
    results.at[label, 'ml_predictions'] = ml_prediction

    
#Extracting the only two columns we need
scrape_results_df = web_scrapedf[['Reviews', 'ml_predictions']]
print(scrape_results_df)
# Out:
#                                               Reviews ml_predictions
# 0   OH MY GOD i think i talk about hattie b's ever...       Positive
# 1   Hattie B's Moreland Ave location gets 4.5 star...       Positive
# 2   This chicken is everything !! Amazingly crisp ...       Positive
# 3   Hattie B's has perfected spicy chicken. This w...       Positive
# 4   So....I'm not really sure what all of the hype...       Negative
# 5   This spot was open with outside patio seating ...       Positive
# 6   I love the food! I am only giving it a 3 for t...       Negative
# 7   Hattie B's chicken is hands down the best hot ...       Positive
# 8   Although the food was super good, the Covid pr...       Positive
# 9   A forever favorite when I visit ATL. My favori...       Positive
# 10  Had the chicken sandwich. Chicken was juicy an...       Positive
# 11  Great food. Arrived when they first opened no ...       Positive
# 12  Hattie B's has been on my radar for a hot seco...       Positive
# 13  The first and last time I had Hattie B's was i...       Positive
# 14  The chicken was great. For spice, I would reco...       Positive
# 15  Overall just good, It's fried chicken in the s...       Positive
# 16  I always wanted to try Hattie's in Nashville a...       Positive
# 17  I'm sorry but I followed the crowd and wanted ...       Negative
# 18  It's my first time here and the place looked c...       Negative
# 19  So the first Hattie Bs I went to was in Nashvi...       Positive

# %%
#Creating list of positive words
positive_wordcloud = scrape_results_df[scrape_results_df['ml_predictions'] == 'Positive']

positivecv = CountVectorizer(analyzer=text_process)   
positive_fit=positivecv.fit_transform(positive_wordcloud['Reviews'])

#creating key value dicitionary pair of counts
positive_word_list = positivecv.get_feature_names();    
positive_count_list = positive_fit.toarray().sum(axis=0)   


#Grouping the words + counts, solving for int64 serialization errors
positive_words = dict(zip(positive_word_list, positive_count_list))
positive_sorted = sorted(positive_words.items(), key=operator.itemgetter(1), reverse=True)
positive_final = [(p[0], int(p[1])) for p in positive_sorted]

#Printing results
#positive_final
# Out:
# [('chicken', 47),
#  ('hot', 19),
#  ('Hattie', 17),
#  ('food', 16),
#  ('Bs', 15),
#  ('sandwich', 15),
#  ('good', 13),
#  ('like', 12),
#  ('time', 12),
#  ('heat', 11),
#  ('line', 11),
#  ('sides', 11),
#  ('great', 10),
#  ('spice', 10),
#  ('also', 9),
#  ('banana', 9),
#  ('get', 9),
#  ('level', 9),
#  ('wings', 9),
#  ('Nashville', 8),
#  ('fried', 8),
#  ('go', 8),
#  ('got', 8),
#  ('greens', 8),
#  ('love', 8),
#  ('Atlanta', 7),
#  ('Ive', 7),
#  ('cheese', 7),
#  ('fries', 7),
#  ('inside', 7),
#  ('little', 7),
#  ('mac', 7),
#  ('order', 7),
#  ('peach', 7),
#  ('place', 7),
#  ('pudding', 7),
#  ('spicy', 7),
#  ('well', 7),
#  ('Hot', 6),
#  ('Mac', 6),
#  ('Southern', 6),
#  ('best', 6),
#  ('better', 6),
#  ('first', 6),
#  ('location', 6),
#  ('outside', 6),
#  ('pimento', 6),
#  ('side', 6),
#  ('think', 6),
#  ('would', 6),
#  ('always', 5),
#  ('around', 5),
#  ('cant', 5),
#  ('cobbler', 5),
#  ('creamy', 5),
#  ('day', 5),
#  ('delicious', 5),
#  ('didnt', 5),
#  ('free', 5),
#  ('juicy', 5),
#  ('parking', 5),
#  ('salad', 5),
#  ('sauce', 5),
#  ('slaw', 5),
#  ('two', 5),
#  ('3', 4),
#  ('Chicken', 4),
#  ('Cluck', 4),
#  ('Hatties', 4),
#  ('Saturday', 4),
#  ('Shut', 4),
#  ('black', 4),
#  ('especially', 4),
#  ('every', 4),
#  ('levels', 4),
#  ('ordered', 4),
#  ('pea', 4),
#  ('pickle', 4),
#  ('recommend', 4),
#  ('refreshing', 4),
#  ('restaurant', 4),
#  ('sweet', 4),
#  ('table', 4),
#  ('theres', 4),
#  ('try', 4),
#  ('visit', 4),
#  ('whole', 4),
#  ('5', 3),
#  ('Mild', 3),
#  ('addition', 3),
#  ('already', 3),
#  ('back', 3),
#  ('beans', 3),
#  ('bit', 3),
#  ('coleslaw', 3),
#  ('different', 3),
#  ('dining', 3),
#  ('dry', 3),
#  ('eating', 3),
#  ('enough', 3),
#  ('even', 3),
#  ('everything', 3),
#  ('eyed', 3),
#  ('famous', 3),
#  ('find', 3),
#  ('flavor', 3),
#  ('give', 3),
#  ('grilled', 3),
#  ('hottest', 3),
#  ('isnt', 3),
#  ('long', 3),
#  ('next', 3),
#  ('nice', 3),
#  ('nothing', 3),
#  ('one', 3),
#  ('options', 3),
#  ('quick', 3),
#  ('say', 3),
#  ('spot', 3),
#  ('spots', 3),
#  ('super', 3),
#  ('taste', 3),
#  ('tea', 3),
#  ('tenders', 3),
#  ('tried', 3),
#  ('us', 3),
#  ('waiting', 3),
#  ('way', 3),
#  ('went', 3),
#  ('worth', 3),
#  ('youre', 3),
#  ('1', 2),
#  ('2', 2),
#  ('2018', 2),
#  ('Although', 2),
#  ('Cobbler', 2),
#  ('French', 2),
#  ('Id', 2),
#  ('Ill', 2),
#  ('Im', 2),
#  ('Medium', 2),
#  ('Outside', 2),
#  ('Peach', 2),
#  ('Pimento', 2),
#  ('WIN', 2),
#  ('able', 2),
#  ('absolutely', 2),
#  ('amount', 2),
#  ('another', 2),
#  ('anything', 2),
#  ('available', 2),
#  ('baked', 2),
#  ('bird', 2),
#  ('bite', 2),
#  ('bread', 2),
#  ('brought', 2),
#  ('bs', 2),
#  ('clear', 2),
#  ('come', 2),
#  ('comes', 2),
#  ('cooked', 2),
#  ('counter', 2),
#  ('crispy', 2),
#  ('crunch', 2),
#  ('crust', 2),
#  ('damn', 2),
#  ('decent', 2),
#  ('definitely', 2),
#  ('desserts', 2),
#  ('die', 2),
#  ('distancing', 2),
#  ('dont', 2),
#  ('door', 2),
#  ('eat', 2),
#  ('enjoyed', 2),
#  ('ever', 2),
#  ('excellent', 2),
#  ('extra', 2),
#  ('fans', 2),
#  ('far', 2),
#  ('favorite', 2),
#  ('fiancé', 2),
#  ('flavors', 2),
#  ('fresh', 2),
#  ('friends', 2),
#  ('goes', 2),
#  ('going', 2),
#  ('gotten', 2),
#  ('hands', 2),
#  ('home', 2),
#  ('honey', 2),
#  ('kick', 2),
#  ('last', 2),
#  ('limited', 2),
#  ('local', 2),
#  ('matter', 2),
#  ('medium', 2),
#  ('menu', 2),
#  ('mustard', 2),
#  ('needed', 2),
#  ('never', 2),
#  ('okay', 2),
#  ('option', 2),
#  ('outstanding', 2),
#  ('packed', 2),
#  ('park', 2),
#  ('patio', 2),
#  ('people', 2),
#  ('perfect', 2),
#  ('phenomenal', 2),
#  ('pickup', 2),
#  ('piece', 2),
#  ('plates', 2),
#  ('put', 2),
#  ('quite', 2),
#  ('ranch', 2),
#  ('really', 2),
#  ('reason', 2),
#  ('remembered', 2),
#  ('right', 2),
#  ('room', 2),
#  ('rub', 2),
#  ('seasoned', 2),
#  ('second', 2),
#  ('situation', 2),
#  ('small', 2),
#  ('soaked', 2),
#  ('social', 2),
#  ('something', 2),
#  ('southern', 2),
#  ('stars', 2),
#  ('still', 2),
#  ('takeout', 2),
#  ('tasted', 2),
#  ('thats', 2),
#  ('though', 2),
#  ('three', 2),
#  ('today', 2),
#  ('trying', 2),
#  ('usually', 2),
#  ('variety', 2),
#  ('waffles', 2),
#  ('waited', 2),
#  ('week', 2),
#  ('world', 2),
#  ('yet', 2),
#  ('10', 1),
#  ('100pm', 1),
#  ('1012', 1),
#  ('1050', 1),
#  ('112', 1),
#  ('12', 1),
#  ('1250pm', 1),
#  ('19', 1),
#  ('35', 1),
#  ('3Everything', 1),
#  ('45', 1),
#  ('9', 1),
#  ('AMAZING', 1),
#  ('ATL', 1),
#  ('According', 1),
#  ('Also', 1),
#  ('Amazingly', 1),
#  ('Arrived', 1),
#  ('Ave', 1),
#  ('B', 1),
#  ('BBQ', 1),
#  ('BOMB', 1),
#  ('Baked', 1),
#  ('Banana', 1),
#  ('Beans', 1),
#  ('COVID19', 1),
#  ('Comeback', 1),
#  ('Covid', 1),
#  ('Covid19', 1),
#  ('Damn', 1),
#  ('Dark', 1),
#  ('Definitely', 1),
#  ('Delectably', 1),
#  ('Delivery', 1),
#  ('Due', 1),
#  ('Enjoyed', 1),
#  ('Every', 1),
#  ('Everything', 1),
#  ('Extremely', 1),
#  ('FAST', 1),
#  ('Fall', 1),
#  ('Fingers', 1),
#  ('First', 1),
#  ('Food', 1),
#  ('Front', 1),
#  ('GOD', 1),
#  ('Give', 1),
#  ('Great', 1),
#  ('HOT', 1),
#  ('Hell', 1),
#  ('HotIn', 1),
#  ('Incredibly', 1),
#  ('Itd', 1),
#  ('Juicy', 1),
#  ('July', 1),
#  ('Jumbo', 1),
#  ('Large', 1),
#  ('Lemonades', 1),
#  ('Louisiana', 1),
#  ('MAAAAAAANNNNN', 1),
#  ('MILD', 1),
#  ('Meal', 1),
#  ('Melrose', 1),
#  ('Moreland', 1),
#  ('New', 1),
#  ('News', 1),
#  ('Next', 1),
#  ('Note', 1),
#  ('OH', 1),
#  ('Oftentimes', 1),
#  ('Order', 1),
#  ('Orleans', 1),
#  ('Overall', 1),
#  ('Page', 1),
#  ('Perfect', 1),
#  ('Plate', 1),
#  ('Popeyes', 1),
#  ('Price', 1),
#  ('Pudding', 1),
#  ('Rich', 1),
#  ('Sandwich', 1),
#  ('SherwinWilliams', 1),
#  ('Sides', 1),
#  ('Soda', 1),
#  ('Soo', 1),
#  ('Speaking', 1),
#  ('Staff', 1),
#  ('Style', 1),
#  ('Sunday', 1),
#  ('Sundays', 1),
#  ('TVs', 1),
#  ('Tennessee', 1),
#  ('Well', 1),
#  ('Wing', 1),
#  ('Wings', 1),
#  ('Would', 1),
#  ('Yelp', 1),
#  ('accidentally', 1),
#  ('add', 1),
#  ('adding', 1),
#  ('additional', 1),
#  ('adjacent', 1),
#  ('admit', 1),
#  ('againnothing', 1),
#  ('ahead', 1),
#  ('allowing', 1),
#  ('allows', 1),
#  ('alright', 1),
#  ('alternate', 1),
#  ('amazing', 1),
#  ('appealing', 1),
#  ('areas', 1),
#  ('arent', 1),
#  ('arrives', 1),
#  ('aware', 1),
#  ('bacon', 1),
#  ('bag', 1),
#  ('balance', 1),
#  ('barely', 1),
#  ('base', 1),
#  ('battered', 1),
#  ('beats', 1),
#  ('beer', 1),
#  ('begin', 1),
#  ('betterI', 1),
#  ('beyond', 1),
#  ('big', 1),
#  ('bigger', 1),
#  ('bitesI', 1),
#  ('bitly34NzGyHSince', 1),
#  ('bitter', 1),
#  ('bothered', 1),
#  ('bottles', 1),
#  ('bottom', 1),
#  ('breaks', 1),
#  ('breast', 1),
#  ('breasts', 1),
#  ('bucket', 1),
#  ('building', 1),
#  ('built', 1),
#  ('bun', 1),
#  ('burn', 1),
#  ('bussing', 1),
#  ('busy', 1),
#  ('buttery', 1),
#  ('calling', 1),
#  ('came', 1),
#  ('cans', 1),
#  ('care', 1),
#  ('careful', 1),
#  ('cause', 1),
#  ('center', 1),
#  ('chains', 1),
#  ('chance', 1),
#  ('chaos', 1),
#  ('chickenThe', 1),
#  ('cobblerI', 1),
#  ('cold', 1),
#  ('cole', 1),
#  ('collard', 1),
#  ('condiment', 1),
#  ('consistent', 1),
#  ('contactless', 1),
#  ('could', 1),
#  ('couldnt', 1),
#  ('covered', 1),
#  ('covid', 1),
#  ('craft', 1),
#  ('cravings', 1),
#  ('crisp', 1),
#  ('crunchy', 1),
#  ('crusty', 1),
#  ('curbside', 1),
#  ('customer', 1),
#  ('cut', 1),
#  ('cuts', 1),
#  ('cylinders', 1),
#  ('dark', 1),
#  ('decided', 1),
#  ('delectable', 1),
#  ('deliberately', 1),
#  ('deliciousness', 1),
#  ('delivery', 1),
#  ('describing', 1),
#  ('deserts', 1),
#  ('dessert', 1),
#  ('dinein', 1),
#  ('dipped', 1),
#  ('dirty', 1),
#  ('disappointing', 1),
#  ('dishes', 1),
#  ('domestic', 1),
#  ('doors', 1),
#  ('dousing', 1),
#  ('draft', 1),
#  ('dressings', 1),
#  ('drink', 1),
#  ('dubious', 1),
#  ('easy', 1),
#  ('eaten', 1),
#  ('eight', 1),
#  ('elated', 1),
#  ('else', 1),
#  ('enforced', 1),
#  ('enjoy', 1),
#  ('enjoyable', 1),
#  ('entire', 1),
#  ('entrance', 1),
#  ('equally', 1),
#  ('establishments', 1),
#  ('excel', 1),
#  ('excited', 1),
#  ('expectations', 1),
#  ('experience', 1),
#  ('eyes', 1),
#  ('eyesAll', 1),
#  ('fair', 1),
#  ('fantastic', 1),
#  ('fastcasual', 1),
#  ('feelings', 1),
#  ('filling', 1),
#  ('finding', 1),
#  ('fingers', 1),
#  ('flames', 1),
#  ('flavorful', 1),
#  ('flavoring', 1),
#  ('folks', 1),
#  ('foodJumbo', 1),
#  ('forever', 1),
#  ('friendly', 1),
#  ('gave', 1),
#  ('generous', 1),
#  ('gets', 1),
#  ('girlfriends', 1),
#  ('giving', 1),
#  ('goodI', 1),
#  ('goodness', 1),
#  ('goopy', 1),
#  ('grab', 1),
#  ('gratifying', 1),
#  ('grease', 1),
#  ('greasy', 1),
#  ('grits', 1),
#  ('group', 1),
#  ('groups', 1),
#  ('handle', 1),
#  ('happy', 1),
#  ('hard', 1),
#  ('hattie', 1),
#  ('havent', 1),
#  ('heard', 1),
#  ('heating', 1),
#  ('higher', 1),
#  ('highly', 1),
#  ('hint', 1),
#  ('hit', 1),
#  ('holding', 1),
#  ('honest', 1),
#  ('honored', 1),
#  ('hope', 1),
#  ('hopefully', 1),
#  ('hotter', 1),
#  ('hours', 1),
#  ('however', 1),
#  ('hypedup', 1),
#  ('ideal', 1),
#  ('imagine', 1),
#  ('impressiveIm', 1),
#  ('inRegardless', 1),
#  ('incredible', 1),
#  ('inhale', 1),
#  ('ive', 1),
#  ('joint', 1),
#  ('juicier', 1),
#  ('jumbo', 1),
#  ('jump', 1),
#  ('know', 1),
#  ('kosher', 1),
#  ('lackluster', 1),
#  ('large', 1),
#  ('leaves', 1),
#  ('leg', 1),
#  ('legs', 1),
#  ('lemonades', 1),
#  ('less', 1),
#  ('let', 1),
#  ('liked', 1),
#  ('likely', 1),
#  ('liking', 1),
#  ('limp', 1),
#  ('lines', 1),
#  ('lingering', 1),
#  ('lol', 1),
#  ('looked', 1),
#  ('looking', 1),
#  ('lot', 1),
#  ('luckyFree', 1),
#  ('lunch', 1),
#  ('made', 1),
#  ('make', 1),
#  ('many', 1),
#  ('masks', 1),
#  ('mayo', 1),
#  ('meal', 1),
#  ('meals', 1),
#  ('meat', 1),
#  ('meats', 1),
#  ('messy', 1),
#  ('met', 1),
#  ('might', 1),
#  ('mild', 1),
#  ('milder', 1),
#  ('milelong', 1),
#  ('mindblowing', 1),
#  ('minutes', 1),
#  ('moist', 1),
#  ('mouth', 1),
#  ('move', 1),
#  ('n', 1),
#  ('napkins', 1),
#  ('naps', 1),
#  ('new', 1),
#  ('normal', 1),
#  ('normally', 1),
#  ('notice', 1),
#  ('online', 1),
#  ('onlyHeres', 1),
#  ('open', 1),
#  ('opened', 1),
#  ('opening', 1),
#  ('opted', 1),
#  ('ordering', 1),
#  ('orders', 1),
#  ('originally', 1),
#  ('overall', 1),
#  ('overflows', 1),
#  ('owned', 1),
#  ('painful', 1),
#  ('part', 1),
#  ('pass', 1),
#  ('pay', 1),
#  ('payments', 1),
#  ('peppervinegar', 1),
#  ('perfected', 1),
#  ('perfection', 1),
#  ('perfectly', 1),
#  ('personally', 1),
#  ('picking', 1),
#  ('pickles', 1),
#  ('pimiento', 1),
#  ('platesandwich', 1),
#  ('pleasantly', 1),
#  ('please', 1),
#  ('pleasurable', 1),
#  ('points', 1),
#  ('popular', 1),
#  ('portion', 1),
#  ('posted', 1),
#  ('potato', 1),
#  ('ppl', 1),
#  ('prefer', 1),
#  ('preferences', 1),
#  ('preferred', 1),
#  ('pretty', 1),
#  ('price', 1),
#  ('probably', 1),
#  ('problems', 1),
#  ('process', 1),
#  ('proof', 1),
#  ('protocols', 1),
#  ('prove', 1),
#  ('provided', 1),
#  ('provides', 1),
#  ('puddings', 1),
#  ('quality', 1),
#  ('quarter', 1),
#  ('quarters', 1),
#  ('quickly', 1),
#  ('radar', 1),
#  ('ranging', 1),
#  ('rather', 1),
#  ('raving', 1),
#  ('realThe', 1),
#  ('reasonable', 1),
#  ('regret', 1),
#  ('remember', 1),
#  ('requiring', 1),
#  ('responsible', 1),
#  ('restaurants', 1),
#  ('return', 1),
#  ('returning', 1),
#  ('ride', 1),
#  ('rightfully', 1),
#  ('ripe', 1),
#  ('rounded', 1),
#  ('run', 1),
#  ('sad', 1),
#  ('salt', 1),
#  ('sandwiches', 1),
#  ('savory', 1),
#  ('scaredThey', 1),
#  ('seasoning', 1),
#  ('seating', 1),
#  ('seatingThe', 1),
#  ('secret', 1),
#  ('see', 1),
#  ('seem', 1),
#  ('seemed', 1),
#  ('selfserve', 1),
#  ('service', 1),
#  ('shooting', 1),
#  ('shot', 1),
#  ('showed', 1),
#  ('sign', 1),
#  ('signage', 1),
#  ('since', 1),
#  ('situationThis', 1),
#  ('six', 1),
#  ('sizes', 1),
#  ('skin', 1),
#  ('slices', 1),
#  ('smooth', 1),
#  ('sniffling', 1),
#  ('soggy', 1),
#  ('solid', 1),
#  ('soon', 1),
#  ('sorry', 1),
#  ('sort', 1),
#  ('souplike', 1),
#  ('south', 1),
#  ('space', 1),
#  ('speak', 1),
#  ('special', 1),
#  ('spent', 1),
#  ('spilled', 1),
#  ('staff', 1),
#  ('state', 1),
#  ('stovetop', 1),
#  ('street', 1),
#  ('strong', 1),
#  ('style', 1),
#  ('subject', 1),
#  ('subtly', 1),
#  ('sunny', 1),
#  ('supplied', 1),
#  ('surely', 1),
#  ('surface', 1),
#  ('surpass', 1),
#  ('surprised', 1),
#  ('sweeter', 1),
#  ('sweetness', 1),
#  ('system', 1),
#  ('tables', 1),
#  ('take', 1),
#  ('taking', 1),
#  ('talk', 1),
#  ('taps', 1),
#  ('tastes', 1),
#  ('tell', 1),
#  ('tender', 1),
#  ('terrible', 1),
#  ('terrific', 1),
#  ('texture', 1),
#  ('thankful', 1),
#  ('thigh', 1),
#  ('thighs', 1),
#  ('thing', 1),
#  ('things', 1),
#  ('thought', 1),
#  ('tight', 1),
#  ('togetherI', 1),
#  ('togo', 1),
#  ('ton', 1),
#  ('tough', 1),
#  ('tryingIf', 1),
#  ('typical', 1),
#  ('unbelievable', 1),
#  ('unless', 1),
#  ('use', 1),
#  ('utensils', 1),
#  ('versa', 1),
#  ('vice', 1),
#  ('wafflesIf', 1),
#  ('wait', 1),
#  ('want', 1),
#  ('wanted', 1),
#  ('water', 1),
#  ('weak', 1),
#  ('wellseasoned', 1),
#  ('wet', 1),
#  ('whenever', 1),
#  ('wing', 1),
#  ('winning', 1),
#  ('wish', 1),
#  ('wonderfullyflavored', 1),
#  ('wont', 1),
#  ('words', 1),
#  ('wouldnt', 1),
#  ('wouldve', 1),
#  ('yall', 1),
#  ('yeah', 1),
#  ('year', 1),
#  ('yikes', 1),
#  ('youll', 1),
#  ('yummy', 1)]

# %%
#Creating the list of negative words
negative_wordcloud = scrape_results_df[scrape_results_df['ml_predictions'] == 'Negative']

negativecv = CountVectorizer(analyzer=text_process)   
negative_fit=negativecv.fit_transform(negative_wordcloud['Reviews'])

#creating key value dicitionary pair of counts
negative_word_list = negativecv.get_feature_names();    
negative_count_list = negative_fit.toarray().sum(axis=0)   


negative_words = dict(zip(negative_word_list, negative_count_list))
negative_sorted = sorted(negative_words.items(), key=operator.itemgetter(1), reverse=True)
negative_final = [(n[0], int(n[1])) for n in negative_sorted]


#negative_final

# %%
#plotting positive word cloud
data = positive_words
# Import packages
import matplotlib.pyplot as plt
# %matplotlib inline
# Define a function to plot word cloud
def plot_cloud(wordcloud):
    # Set figure size
    plt.figure(figsize=(40, 30))
    # Display image
    plt.imshow(wordcloud) 
    # No axis details
    plt.axis("off");
    
    
# Import package
from wordcloud import WordCloud, STOPWORDS
# Generate word cloud
wordcloud = WordCloud(width = 3000, height = 1000, random_state=1, background_color='salmon', colormap='Pastel1', collocations=False, stopwords = STOPWORDS).generate_from_frequencies(data)
# Plot
plot_cloud(wordcloud)

# %%
#Plotting negative words
data = negative_words
# Import packages
import matplotlib.pyplot as plt
# %matplotlib inline
# Define a function to plot word cloud
def plot_cloud(wordcloud):
    # Set figure size
    plt.figure(figsize=(40, 30))
    # Display image
    plt.imshow(wordcloud) 
    # No axis details
    plt.axis("off");
    
    
# Import package
from wordcloud import WordCloud, STOPWORDS
# Generate word cloud
wordcloud = WordCloud(width = 3000, height = 1000, random_state=1, background_color='salmon', colormap='Pastel1', collocations=False, stopwords = STOPWORDS).generate_from_frequencies(data)
# Plot
plot_cloud(wordcloud)

# %%
#vectorizing, tokenizing data

from sklearn.feature_extraction.text import CountVectorizer

cv = CountVectorizer(analyzer=text_process)   
cv_fit=cv.fit_transform(df4['text'])    


#creating key value dicitionary pair of counts
word_list = cv.get_feature_names();    
count_list = cv_fit.toarray().sum(axis=0)   


final = dict(zip(word_list, count_list))
print(final)

import operator
sorted(final.items(), key=operator.itemgetter(1), reverse=True)

# %%
#vectorizing, tokenizing data

from sklearn.feature_extraction.text import CountVectorizer

cv = CountVectorizer(analyzer=text_process)   
cv_fit=cv.fit_transform(df4['text'])

# %%
#creating key value dicitionary pair of counts
word_list = cv.get_feature_names();    
count_list = cv_fit.toarray().sum(axis=0)   


final = dict(zip(word_list, count_list))
print(final)

# %%
#outdated
bow_transformer = CountVectorizer(analyzer=text_process).fit(x)

# %%
#looking at the words from highest to lowest frequency
import operator
sorted(final.items(), key=operator.itemgetter(1), reverse=True)
# Out:
# [('food', 6451),
#  ('place', 5174),
#  ('good', 3554),
#  ('great', 3389),
#  ('service', 3129),
#  ('time', 2868),
#  ('back', 2756),
#  ('like', 2623),
#  ('get', 2443),
#  ('one', 2259),
#  ('go', 2252),
#  ('restaurant', 2069),
#  ('order', 2022),
#  ('us', 1991),
#  ('would', 1974),
#  ('delicious', 1836),
#  ('ordered', 1722),
#  ('always', 1690),
#  ('really', 1682),
#  ('best', 1681),
#  ('chicken', 1642),
#  ('menu', 1576),
#  ('amazing', 1573),
#  ('try', 1560),
#  ('love', 1559),
#  ('also', 1520),
#  ('got', 1511),
#  ('Ive', 1503),
#  ('even', 1482),
#  ('Im', 1426),
#  ('dont', 1379),
#  ('wait', 1366),
#  ('friendly', 1343),
#  ('come', 1325),
#  ('staff', 1325),
#  ('never', 1245),
#  ('came', 1243),
#  ('well', 1238),
#  ('definitely', 1171),
#  ('eat', 1166),
#  ('recommend', 1159),
#  ('fresh', 1153),
#  ('nice', 1128),
#  ('experience', 1114),
#  ('ever', 1098),
#  ('didnt', 1065),
#  ('make', 1050),
#  ('could', 1038),
#  ('made', 1033),
#  ('pizza', 1030),
#  ('people', 1028),
#  ('first', 1013),
#  ('favorite', 993),
#  ('said', 992),
#  ('table', 970),
#  ('sauce', 958),
#  ('meal', 952),
#  ('much', 931),
#  ('salad', 931),
#  ('went', 924),
#  ('Great', 918),
#  ('going', 897),
#  ('little', 889),
#  ('meat', 887),
#  ('night', 875),
#  ('say', 855),
#  ('know', 843),
#  ('right', 832),
#  ('everything', 826),
#  ('minutes', 823),
#  ('way', 820),
#  ('cheese', 817),
#  ('times', 809),
#  ('dinner', 803),
#  ('want', 801),
#  ('location', 800),
#  ('lunch', 794),
#  ('dishes', 793),
#  ('take', 773),
#  ('every', 770),
#  ('tried', 768),
#  ('hot', 762),
#  ('sure', 755),
#  ('better', 752),
#  ('two', 751),
#  ('vegan', 740),
#  ('2', 734),
#  ('give', 732),
#  ('asked', 721),
#  ('server', 718),
#  ('many', 709),
#  ('cant', 707),
#  ('new', 697),
#  ('beef', 696),
#  ('dish', 675),
#  ('told', 674),
#  ('around', 673),
#  ('customer', 673),
#  ('bar', 668),
#  ('excellent', 665),
#  ('5', 655),
#  ('super', 655),
#  ('took', 655),
#  ('worth', 649),
#  ('cream', 645),
#  ('day', 639),
#  ('ice', 632),
#  ('pork', 632),
#  ('taste', 630),
#  ('soup', 626),
#  ('next', 625),
#  ('think', 622),
#  ('still', 620),
#  ('awesome', 617),
#  ('long', 614),
#  ('spot', 610),
#  ('something', 605),
#  ('area', 603),
#  ('coming', 603),
#  ('Vegas', 600),
#  ('small', 595),
#  ('places', 588),
#  ('bad', 587),
#  ('family', 586),
#  ('fried', 579),
#  ('friends', 578),
#  ('visit', 578),
#  ('drinks', 575),
#  ('since', 574),
#  ('rice', 567),
#  ('flavor', 564),
#  ('home', 561),
#  ('last', 560),
#  ('3', 559),
#  ('perfect', 559),
#  ('manager', 556),
#  ('find', 547),
#  ('side', 545),
#  ('thing', 545),
#  ('atmosphere', 543),
#  ('pretty', 538),
#  ('see', 531),
#  ('pho', 527),
#  ('wasnt', 525),
#  ('different', 524),
#  ('sandwich', 523),
#  ('quality', 520),
#  ('sushi', 517),
#  ('drink', 513),
#  ('lot', 508),
#  ('eating', 507),
#  ('Charlotte', 500),
#  ('restaurants', 496),
#  ('another', 491),
#  ('clean', 491),
#  ('bread', 490),
#  ('spicy', 490),
#  ('shrimp', 488),
#  ('Chinese', 487),
#  ('wanted', 487),
#  ('Food', 486),
#  ('away', 483),
#  ('tea', 482),
#  ('feel', 481),
#  ('top', 480),
#  ('fries', 468),
#  ('happy', 467),
#  ('youre', 467),
#  ('enough', 463),
#  ('disappointed', 462),
#  ('sweet', 460),
#  ('left', 457),
#  ('looking', 456),
#  ('tasty', 452),
#  ('bit', 446),
#  ('husband', 446),
#  ('full', 444),
#  ('special', 442),
#  ('price', 441),
#  ('things', 441),
#  ('big', 440),
#  ('work', 436),
#  ('Everything', 435),
#  ('busy', 434),
#  ('waitress', 431),
#  ('Thai', 429),
#  ('ask', 429),
#  ('tell', 427),
#  ('absolutely', 425),
#  ('fast', 425),
#  ('loved', 425),
#  ('Service', 418),
#  ('10', 417),
#  ('anything', 416),
#  ('tasted', 415),
#  ('years', 412),
#  ('wings', 406),
#  ('Love', 405),
#  ('wonderful', 404),
#  ('must', 403),
#  ('prices', 403),
#  ('cooked', 398),
#  ('town', 398),
#  ('decided', 395),
#  ('large', 394),
#  ('need', 393),
#  ('crispy', 390),
#  ('options', 390),
#  ('fantastic', 389),
#  ('waiting', 384),
#  ('though', 383),
#  ('far', 382),
#  ('friend', 382),
#  ('attentive', 380),
#  ('served', 379),
#  ('fish', 378),
#  ('4', 377),
#  ('gave', 376),
#  ('wont', 372),
#  ('cold', 371),
#  ('hour', 371),
#  ('line', 368),
#  ('tacos', 368),
#  ('else', 365),
#  ('thought', 365),
#  ('tables', 364),
#  ('found', 362),
#  ('owner', 358),
#  ('check', 357),
#  ('put', 356),
#  ('fun', 355),
#  ('kind', 355),
#  ('review', 355),
#  ('business', 354),
#  ('highly', 353),
#  ('dessert', 350),
#  ('enjoyed', 350),
#  ('quick', 349),
#  ('breakfast', 347),
#  ('items', 346),
#  ('everyone', 345),
#  ('wrong', 345),
#  ('vegetarian', 344),
#  ('enjoy', 343),
#  ('look', 343),
#  ('looked', 343),
#  ('wine', 343),
#  ('Italian', 341),
#  ('stars', 341),
#  ('without', 341),
#  ('brought', 337),
#  ('drive', 336),
#  ('week', 334),
#  ('free', 333),
#  ('half', 333),
#  ('rolls', 333),
#  ('almost', 332),
#  ('comes', 331),
#  ('hard', 331),
#  ('inside', 330),
#  ('course', 327),
#  ('thats', 326),
#  ('care', 325),
#  ('least', 325),
#  ('let', 325),
#  ('Ill', 324),
#  ('real', 323),
#  ('dining', 321),
#  ('wife', 321),
#  ('portions', 320),
#  ('seated', 318),
#  ('usually', 318),
#  ('waiter', 318),
#  ('belly', 317),
#  ('customers', 317),
#  ('reviews', 317),
#  ('1', 316),
#  ('huge', 315),
#  ('old', 314),
#  ('Chicken', 313),
#  ('chef', 313),
#  ('getting', 313),
#  ('actually', 308),
#  ('house', 307),
#  ('couldnt', 306),
#  ('Best', 303),
#  ('Definitely', 303),
#  ('One', 303),
#  ('used', 303),
#  ('point', 302),
#  ('open', 301),
#  ('probably', 301),
#  ('burger', 299),
#  ('called', 298),
#  ('today', 297),
#  ('trying', 297),
#  ('ate', 295),
#  ('close', 295),
#  ('Also', 294),
#  ('coffee', 294),
#  ('nothing', 294),
#  ('bring', 293),
#  ('helpful', 291),
#  ('couple', 290),
#  ('extremely', 290),
#  ('makes', 290),
#  ('plate', 289),
#  ('stop', 289),
#  ('walked', 289),
#  ('Veggie', 286),
#  ('hours', 284),
#  ('quite', 284),
#  ('bowl', 282),
#  ('pasta', 282),
#  ('Chef', 280),
#  ('front', 279),
#  ('person', 279),
#  ('pay', 278),
#  ('rude', 277),
#  ('extra', 275),
#  ('done', 273),
#  ('House', 271),
#  ('roll', 271),
#  ('water', 271),
#  ('authentic', 269),
#  ('whole', 269),
#  ('money', 268),
#  ('group', 267),
#  ('orders', 267),
#  ('several', 267),
#  ('chocolate', 266),
#  ('Id', 264),
#  ('ordering', 263),
#  ('party', 263),
#  ('waited', 263),
#  ('sit', 262),
#  ('selection', 261),
#  ('First', 260),
#  ('return', 260),
#  ('egg', 259),
#  ('serve', 259),
#  ('often', 258),
#  ('able', 256),
#  ('curry', 256),
#  ('soon', 256),
#  ('name', 255),
#  ('Soul', 254),
#  ('doesnt', 253),
#  ('noodles', 253),
#  ('ingredients', 252),
#  ('leave', 252),
#  ('second', 252),
#  ('amount', 251),
#  ('beer', 251),
#  ('making', 251),
#  ('guy', 249),
#  ('star', 248),
#  ('later', 247),
#  ('yummy', 247),
#  ('20', 246),
#  ('perfectly', 246),
#  ('outside', 245),
#  ('regular', 245),
#  ('three', 245),
#  ('meals', 244),
#  ('yet', 244),
#  ('especially', 243),
#  ('flavorful', 243),
#  ('sat', 242),
#  ('use', 240),
#  ('finally', 239),
#  ('kids', 239),
#  ('door', 238),
#  ('worst', 237),
#  ('15', 236),
#  ('keep', 235),
#  ('Pho', 234),
#  ('dog', 234),
#  ('end', 234),
#  ('wish', 233),
#  ('flavors', 231),
#  ('date', 230),
#  ('part', 230),
#  ('BBQ', 229),
#  ('eaten', 229),
#  ('Dont', 228),
#  ('style', 228),
#  ('Good', 227),
#  ('arrived', 227),
#  ('high', 227),
#  ('walk', 227),
#  ('instead', 226),
#  ('veggie', 226),
#  ('6', 223),
#  ('impressed', 223),
#  ('started', 222),
#  ('variety', 221),
#  ('cool', 220),
#  ('may', 220),
#  ('Highly', 219),
#  ('ready', 219),
#  ('someone', 219),
#  ('steak', 219),
#  ('bite', 218),
#  ('salads', 217),
#  ('Oh', 216),
#  ('plates', 216),
#  ('reasonable', 216),
#  ('already', 215),
#  ('entire', 215),
#  ('green', 215),
#  ('30', 213),
#  ('believe', 213),
#  ('chips', 213),
#  ('offer', 212),
#  ('room', 211),
#  ('birthday', 210),
#  ('quickly', 210),
#  ('less', 209),
#  ('seating', 209),
#  ('Well', 207),
#  ('kitchen', 207),
#  ('Amazing', 206),
#  ('counter', 206),
#  ('fact', 205),
#  ('appetizer', 204),
#  ('cook', 204),
#  ('felt', 204),
#  ('live', 204),
#  ('ago', 203),
#  ('call', 203),
#  ('eggplant', 203),
#  ('garlic', 203),
#  ('dogs', 202),
#  ('Went', 201),
#  ('boyfriend', 201),
#  ('local', 201),
#  ('recommended', 201),
#  ('saw', 201),
#  ('Las', 200),
#  ('isnt', 200),
#  ('servers', 200),
#  ('size', 200),
#  ('warm', 200),
#  ('Excellent', 199),
#  ('glad', 199),
#  ('prepared', 198),
#  ('bill', 197),
#  ('start', 197),
#  ('portion', 196),
#  ('twice', 196),
#  ('sandwiches', 195),
#  ('store', 195),
#  ('anyone', 193),
#  ('priced', 193),
#  ('employees', 192),
#  ('life', 192),
#  ('working', 192),
#  ('grilled', 191),
#  ('pick', 191),
#  ('tastes', 190),
#  ('havent', 189),
#  ('terrible', 188),
#  ('year', 188),
#  ('fan', 187),
#  ('deal', 186),
#  ('orange', 186),
#  ('reason', 186),
#  ('Really', 185),
#  ('guys', 185),
#  ('unique', 185),
#  ('white', 184),
#  ('either', 182),
#  ('veggies', 182),
#  ('horrible', 181),
#  ('job', 181),
#  ('Korean', 180),
#  ('Overall', 179),
#  ('delivery', 179),
#  ('healthy', 179),
#  ('lady', 179),
#  ('light', 179),
#  ('wouldnt', 179),
#  ('behind', 178),
#  ('expect', 178),
#  ('help', 178),
#  ('literally', 178),
#  ('music', 178),
#  ('meats', 177),
#  ('seemed', 177),
#  ('Vietnamese', 176),
#  ('incredible', 176),
#  ('maybe', 176),
#  ('remember', 176),
#  ('Even', 175),
#  ('add', 175),
#  ('ended', 175),
#  ('Every', 174),
#  ('street', 174),
#  ('together', 173),
#  ('spring', 172),
#  ('decor', 171),
#  ('tip', 171),
#  ('gem', 170),
#  ('man', 170),
#  ('chili', 169),
#  ('choices', 169),
#  ('evening', 169),
#  ('parking', 169),
#  ('Asian', 168),
#  ('Cant', 168),
#  ('choose', 168),
#  ('sitting', 168),
#  ('days', 167),
#  ('favorites', 167),
#  ('broth', 166),
#  ('completely', 166),
#  ('tofu', 166),
#  ('cheap', 165),
#  ('trip', 165),
#  ('However', 164),
#  ('choice', 164),
#  ('greeted', 163),
#  ('games', 162),
#  ('lamb', 162),
#  ('needed', 162),
#  ('phone', 162),
#  ('Thank', 161),
#  ('dirty', 161),
#  ('dry', 161),
#  ('early', 161),
#  ('forward', 161),
#  ('looks', 161),
#  ('opened', 161),
#  ('owners', 161),
#  ('bacon', 160),
#  ('girl', 160),
#  ('mind', 160),
#  ('texture', 160),
#  ('12', 159),
#  ('cooking', 159),
#  ('cute', 159),
#  ('sauces', 159),
#  ('easy', 158),
#  ('plenty', 158),
#  ('saying', 157),
#  ('tender', 157),
#  ('theres', 157),
#  ('theyre', 157),
#  ('Yelp', 156),
#  ('ok', 156),
#  ('stuff', 156),
#  ('truly', 156),
#  ('past', 155),
#  ('received', 155),
#  ('specials', 155),
#  ('fine', 154),
#  ('stopped', 154),
#  ('change', 153),
#  ('gets', 153),
#  ('red', 153),
#  ('youll', 153),
#  ('Never', 152),
#  ('establishment', 152),
#  ('taking', 152),
#  ('Delicious', 151),
#  ('near', 151),
#  ('offered', 151),
#  ('along', 150),
#  ('charge', 150),
#  ('frozen', 149),
#  ('pleasant', 149),
#  ('vegetables', 149),
#  ('Saturday', 148),
#  ('hungry', 148),
#  ('paid', 148),
#  ('soft', 148),
#  ('totally', 148),
#  ('Chili', 147),
#  ('crust', 147),
#  ('decent', 147),
#  ('hostess', 147),
#  ('immediately', 147),
#  ('mouth', 147),
#  ('list', 146),
#  ('burgers', 145),
#  ('world', 145),
#  ('packed', 144),
#  ('pieces', 144),
#  ('empty', 143),
#  ('juice', 143),
#  ('seem', 143),
#  ('share', 143),
#  ('short', 143),
#  ('Kenny', 142),
#  ('dressing', 142),
#  ('gone', 142),
#  ('Would', 141),
#  ('others', 141),
#  ('outstanding', 141),
#  ('Came', 140),
#  ('Sunday', 140),
#  ('Vic', 140),
#  ('across', 140),
#  ('available', 140),
#  ('combo', 140),
#  ('piece', 140),
#  ('thru', 140),
#  ('7', 139),
#  ('cake', 139),
#  ('cocktails', 139),
#  ('excited', 139),
#  ('late', 139),
#  ('liked', 139),
#  ('option', 139),
#  ('run', 139),
#  ('understand', 139),
#  ('added', 138),
#  ('ambiance', 138),
#  ('cannot', 138),
#  ('heard', 138),
#  ('kept', 138),
#  ('needs', 138),
#  ('poor', 138),
#  ('visiting', 138),
#  ('homemade', 137),
#  ('might', 137),
#  ('says', 137),
#  ('sides', 137),
#  ('tasting', 137),
#  ('vibe', 137),
#  ('bartender', 136),
#  ('bland', 136),
#  ('Scottsdale', 135),
#  ('attitude', 135),
#  ('however', 135),
#  ('Beef', 134),
#  ('Ordered', 134),
#  ('giving', 134),
#  ('mean', 133),
#  ('slow', 133),
#  ('tapas', 131),
#  ('treat', 131),
#  ('tuna', 131),
#  ('dip', 130),
#  ('problem', 130),
#  ('stuffed', 130),
#  ('surprised', 130),
#  ('taken', 130),
#  ('8', 129),
#  ('Super', 129),
#  ('knew', 129),
#  ('lots', 129),
#  ('mushrooms', 129),
#  ('Wow', 128),
#  ('game', 128),
#  ('guess', 128),
#  ('show', 128),
#  ('returning', 127),
#  ('Pizza', 126),
#  ('beyond', 126),
#  ('visited', 126),
#  ('AMAZING', 125),
#  ('LOVE', 125),
#  ('card', 125),
#  ('neighborhood', 125),
#  ('patio', 125),
#  ('perfection', 125),
#  ('simple', 125),
#  ('sour', 125),
#  ('welcoming', 125),
#  ('eggs', 124),
#  ('honestly', 124),
#  ('single', 124),
#  ('item', 123),
#  ('lettuce', 123),
#  ('walking', 123),
#  ('Everyone', 122),
#  ('Staff', 122),
#  ('Vegan', 122),
#  ('black', 122),
#  ('burrito', 122),
#  ('etc', 122),
#  ('five', 122),
#  ('hit', 122),
#  ('seems', 122),
#  ('seen', 122),
#  ('based', 121),
#  ('cut', 121),
#  ('die', 121),
#  ('including', 121),
#  ('main', 121),
#  ('ones', 121),
#  ('reservations', 121),
#  ('100', 120),
#  ('Bowl', 120),
#  ('brisket', 120),
#  ('weekend', 120),
#  ('Go', 119),
#  ('generous', 119),
#  ('given', 119),
#  ('management', 119),
#  ('tonight', 119),
#  ('Always', 118),
#  ('chance', 118),
#  ('plus', 118),
#  ('yes', 118),
#  ('appetizers', 117),
#  ('beans', 117),
#  ('exactly', 117),
#  ('hope', 117),
#  ('noodle', 117),
#  ('seafood', 117),
#  ('serving', 117),
#  ('smile', 117),
#  ('toppings', 117),
#  ('disappoint', 116),
#  ('talk', 116),
#  ('type', 116),
#  ('45', 115),
#  ('Absolutely', 115),
#  ('Lupo', 115),
#  ('Nice', 115),
#  ('Pork', 115),
#  ('Toronto', 115),
#  ('covered', 115),
#  ('moved', 115),
#  ('set', 115),
#  ('space', 115),
#  ('thin', 115),
#  ('Try', 114),
#  ('seat', 114),
#  ('son', 114),
#  ('werent', 114),
#  ('Yes', 113),
#  ('delivered', 113),
#  ('desserts', 113),
#  ('glass', 113),
#  ('lobster', 113),
#  ('morning', 113),
#  ('strip', 113),
#  ('finished', 112),
#  ('miss', 112),
#  ('salty', 112),
#  ('simply', 112),
#  ('strawberry', 112),
#  ('Cafe', 111),
#  ('cup', 111),
#  ('environment', 111),
#  ('located', 111),
#  ('bean', 110),
#  ('crazy', 110),
#  ('feeling', 110),
#  ('mins', 110),
#  ('noticed', 110),
#  ('rest', 110),
#  ('window', 110),
#  ('bbq', 109),
#  ('expected', 109),
#  ('min', 109),
#  ('minute', 109),
#  ('month', 109),
#  ('number', 109),
#  ('onions', 109),
#  ('stay', 109),
#  ('talking', 109),
#  ('value', 109),
#  ('brown', 108),
#  ('city', 108),
#  ('cozy', 108),
#  ('daughter', 108),
#  ('expensive', 108),
#  ('fabulous', 108),
#  ('finish', 108),
#  ('mention', 108),
#  ('please', 108),
#  ('seriously', 108),
#  ('shop', 108),
#  ('accommodating', 107),
#  ('anywhere', 107),
#  ('salsa', 107),
#  ('Awesome', 106),
#  ('hands', 106),
#  ('milk', 106),
#  ('salt', 106),
#  ('seasoned', 106),
#  ('sorry', 106),
#  ('New', 105),
#  ('baked', 105),
#  ('floor', 105),
#  ('incredibly', 105),
#  ('traditional', 105),
#  ('due', 104),
#  ('forgot', 104),
#  ('greasy', 104),
#  ('issue', 104),
#  ('phenomenal', 104),
#  ('Zipps', 103),
#  ('awful', 103),
#  ('beautiful', 103),
#  ('longer', 103),
#  ('reservation', 103),
#  ('arent', 102),
#  ('comfortable', 102),
#  ('entrees', 102),
#  ('lovely', 102),
#  ('onion', 102),
#  ('pepper', 102),
#  ('tomato', 102),
#  ('Japanese', 101),
#  ('checked', 101),
#  ('entree', 101),
#  ('forget', 101),
#  ('okay', 101),
#  ('online', 101),
#  ('overall', 101),
#  ('Thanks', 100),
#  ('changed', 100),
#  ('hidden', 100),
#  ('lol', 100),
#  ('mom', 100),
#  ('multiple', 100),
#  ('soda', 100),
#  ('bowls', 99),
#  ('craving', 99),
#  ('duck', 99),
#  ('four', 99),
#  ('knowledgeable', 99),
#  ('recently', 99),
#  ('surprise', 99),
#  ('Friday', 98),
#  ('Thats', 98),
#  ('car', 98),
#  ('chose', 98),
#  ('low', 98),
#  ('months', 98),
#  ('oh', 98),
#  ('play', 98),
#  ('young', 98),
#  ('butter', 97),
#  ('guests', 97),
#  ('leaving', 97),
#  ('rather', 97),
#  ('reasonably', 97),
#  ('salmon', 97),
#  ('satisfied', 97),
#  ('calamari', 96),
#  ('helped', 96),
#  ('mix', 96),
#  ('recommendations', 96),
#  ('shared', 96),
#  ('sometimes', 96),
#  ('broccoli', 95),
#  ('dine', 95),
#  ('expectations', 95),
#  ('explained', 95),
#  ('joint', 95),
#  ('ribs', 95),
#  ('speak', 95),
#  ('split', 95),
#  ('Man', 94),
#  ('Sugar', 94),
#  ('average', 94),
#  ('filling', 94),
#  ('lived', 94),
#  ('although', 93),
#  ('asking', 93),
#  ('cashier', 93),
#  ('level', 93),
#  ('locations', 93),
#  ('pizzas', 93),
#  ('potatoes', 93),
#  ('read', 93),
#  ('soups', 93),
#  ('spinach', 93),
#  ('stand', 93),
#  ('takes', 93),
#  ('waste', 93),
#  ('weve', 93),
#  ('Finally', 92),
#  ('Loved', 92),
#  ('absolute', 92),
#  ('corn', 92),
#  ('head', 92),
#  ('knows', 92),
#  ('rare', 92),
#  ('takeout', 92),
#  ('yelp', 92),
#  ('Mexican', 91),
#  ('app', 91),
#  ('beers', 91),
#  ('cash', 91),
#  ('downtown', 91),
#  ('exceptional', 91),
#  ('filled', 91),
#  ('idea', 91),
#  ('pulled', 91),
#  ('soggy', 91),
#  ('attention', 90),
#  ('closed', 90),
#  ('meatballs', 90),
#  ('n', 90),
#  ('refreshing', 90),
#  ('thai', 90),
#  ('worked', 90),
#  ('Meat', 89),
#  ('alone', 89),
#  ('cafe', 89),
#  ('coconut', 89),
#  ('corner', 89),
#  ('disgusting', 89),
#  ('employee', 89),
#  ('hand', 89),
#  ('kid', 89),
#  ('missing', 89),
#  ('upon', 89),
#  ('de', 88),
#  ('per', 88),
#  ('whatever', 88),
#  ('wrap', 88),
#  ('BEST', 87),
#  ('Fresh', 87),
#  ('Lets', 87),
#  ('Since', 87),
#  ('casual', 87),
#  ('foods', 87),
#  ('turned', 87),
#  ('Spicy', 86),
#  ('basically', 86),
#  ('negative', 86),
#  ('Crispy', 85),
#  ('Friendly', 85),
#  ('box', 85),
#  ('cost', 85),
#  ('face', 85),
#  ('grab', 85),
#  ('happened', 85),
#  ('mushroom', 85),
#  ('potato', 85),
#  ('sign', 85),
#  ('tiny', 85),
#  ('truffle', 85),
#  ('welcome', 85),
#  ('25', 84),
#  ('Fried', 84),
#  ('except', 84),
#  ('girls', 84),
#  ('grill', 84),
#  ('usual', 84),
#  ('watch', 84),
#  ('Get', 83),
#  ('bag', 83),
#  ('charged', 83),
#  ('cuisine', 83),
#  ('favourite', 83),
#  ('goes', 83),
#  ('iced', 83),
#  ('Kung', 82),
#  ('goat', 82),
#  ('hair', 82),
#  ('loud', 82),
#  ('loves', 82),
#  ('menus', 82),
#  ('oil', 82),
#  ('sad', 82),
#  ('true', 82),
#  ('weeks', 82),
#  ('Got', 81),
#  ('Theres', 81),
#  ('addition', 81),
#  ('become', 81),
#  ('class', 81),
#  ('fair', 81),
#  ('hotel', 81),
#  ('obviously', 81),
#  ('questions', 81),
#  ('rich', 81),
#  ('thank', 81),
#  ('thick', 81),
#  ('within', 81),
#  ('Salad', 80),
#  ('Weve', 80),
#  ('brunch', 80),
#  ('crab', 80),
#  ('easily', 80),
#  ('general', 80),
#  ('mixed', 80),
#  ('popular', 80),
#  ('thinking', 80),
#  ('tomatoes', 80),
#  ('treated', 80),
#  ('French', 79),
#  ('Like', 79),
#  ('Seriously', 79),
#  ('ahead', 79),
#  ('bottle', 79),
#  ('chill', 79),
#  ('explain', 79),
#  ('included', 79),
#  ('interesting', 79),
#  ...]

# %%
# Import packages
import matplotlib.pyplot as plt
# %matplotlib inline
# Define a function to plot word cloud
def plot_cloud(wordcloud):
    # Set figure size
    plt.figure(figsize=(40, 30))
    # Display image
    plt.imshow(wordcloud) 
    # No axis details
    plt.axis("off");

# %%
# Import packages
import matplotlib.pyplot as plt
# %matplotlib inline
# Define a function to plot word cloud
def plot_cloud(wordcloud):
    # Set figure size
    plt.figure(figsize=(40, 30))
    # Display image
    plt.imshow(wordcloud) 
    # No axis details
    plt.axis("off");
    
    
# Import package
from wordcloud import WordCloud, STOPWORDS
# Generate word cloud
wordcloud = WordCloud(width = 3000, height = 1000, random_state=1, background_color='salmon', colormap='Pastel1', collocations=False, stopwords = STOPWORDS).generate_from_frequencies(final)
# Plot
plot_cloud(wordcloud)

# %%
# Import package
from wordcloud import WordCloud, STOPWORDS
# Generate word cloud
wordcloud = WordCloud(width = 3000, height = 1000, random_state=1, background_color='salmon', colormap='Pastel1', collocations=False, stopwords = STOPWORDS).generate_from_frequencies(final)
# Plot
plot_cloud(wordcloud)

# %%
print(STOPWORDS)
# Out:
# {'however', 'other', 'then', 'below', 'through', 'that', "he'll", "it's", 'between', "where's", 'under', 'above', 'been', 'there', 'k', 'we', 'was', 'at', "wouldn't", "they've", 'to', 'for', 'just', "haven't", 'otherwise', 'and', 'having', 'than', 'its', 'her', 'hers', "can't", "hasn't", 'who', "she'll", 'http', 'should', 'yourself', 'because', 'being', "we've", "wasn't", "hadn't", 'on', 'www', 'ours', 'with', 'you', 'your', 'or', "i'm", 'in', "shan't", "couldn't", "isn't", 'did', 'do', 'own', 'be', "let's", 'she', "they'll", 'each', 'would', 'they', 'theirs', 'off', 'i', "here's", "they'd", 'could', 'like', 'both', "i'd", "we're", 'this', 'not', 'have', 'ever', 'r', 'any', "mustn't", 'all', 'has', 'while', 'why', 'me', 'about', 'before', 'but', "you're", 'by', 'few', "he'd", 'had', "shouldn't", 'these', 'same', "she's", 'so', "there's", "they're", 'those', 'an', 'are', "don't", "i'll", 'which', 'until', "you've", 'therefore', 'into', 'am', 'again', 'from', 'if', 'myself', 'it', 'only', 'the', 'over', 'their', 'too', 'of', 'a', 'ought', 'our', "i've", "weren't", "you'd", "when's", 'shall', "won't", 'most', 'doing', 'get', "doesn't", "we'd", 'does', "aren't", 'no', 'how', 'can', "didn't", 'yourselves', 'when', 'more', "what's", 'once', 'itself', 'as', "who's", 'also', "she'd", 'after', 'whom', 'such', 'very', 'cannot', 'his', 'my', 'ourselves', "you'll", 'them', 'else', "he's", 'some', 'nor', 'com', 'himself', 'yours', 'were', 'him', "we'll", 'where', 'during', 'he', "that's", "how's", "why's", 'down', 'is', 'hence', 'against', 'herself', 'further', 'themselves', 'what', 'since', 'here', 'out', 'up'}

# %%
#converting into a sparse matrix (will have to repeat for web-scraped data)
X = cv.transform(x)

# %%
print('Shape of Sparse Matrix: ', X.shape)
print('Amount of Non-Zero occurrences: ', X.nnz)
# Percentage of non-zero values
density = (100.0 * X.nnz / (X.shape[0] * X.shape[1]))
print('Density: {}'.format((density)))
# Out:
# Shape of Sparse Matrix:  (10000, 27438)
# Amount of Non-Zero occurrences:  406349
# Density: 0.14809716451636418

# %%
#Splitting data
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=101)

# %%
#importing specific ML model, fitting model
from sklearn.naive_bayes import MultinomialNB
nb = MultinomialNB()
nb.fit(X_train, y_train)

#testing model
predictions = nb.predict(X_test)

# %%
from sklearn.metrics import confusion_matrix, classification_report
print(confusion_matrix(y_test, predictions))
print('\n')
print(classification_report(y_test, predictions))
# Out:
# [[ 612   69]
#  [  44 2275]]
#
#
#               precision    recall  f1-score   support
#
#            1       0.93      0.90      0.92       681
#            5       0.97      0.98      0.98      2319
#
#     accuracy                           0.96      3000
#    macro avg       0.95      0.94      0.95      3000
# weighted avg       0.96      0.96      0.96      3000

# %%
#Find positive review
positive_review = review[4:5]
print(f" Positive Review Text: {positive_review.text}")
positive_review['text']
# Out:
#  Positive Review Text: 5    The cheese steak is great here. The guys cooki...
# Name: text, dtype: object
# 5    The cheese steak is great here. The guys cooki...
# Name: text, dtype: object

# %%
#Getting Sample Review
from random import randint
n = randint(1, len(df4))
#n = 3291
print(f"Randomizer ID: {n}\n---------------------------------")

#Pulling up info for sample review
sample_review = df4['text'][n]
actual = df4['review_stars'][n]
restaurant = df4['name'][n]
# print(sample_review)
# print(sample_score)
      
      
#Transform random review
review_transformed = cv.transform([sample_review])
      
      
#generating predicted score value      
predicted = nb.predict(review_transformed)[0]

if predicted == actual:
    status = 'Success!!'
else: status = 'Fail'
        
print(f"Restaurant Name: {restaurant}")
print(f"Review Text: {sample_review} \n")
print(f"ML Predicted Yelp Review Score: {predicted}")
print(f"Actual Yelp Review Score: {actual}\n")
print(f"Status: {status}")
# Out:
# Randomizer ID: 38
# ---------------------------------
# Restaurant Name: Amir
# Review Text: 1h15 d'attente pour recevoir mon repas. Le tout était froid et quand j'ai appelé au restaurant ils m'ont racrocher au nez. Ridicule !!
#
# ML Predicted Yelp Review Score: Positive
# Actual Yelp Review Score: 1
#
# Status: Fail

# %%
#Getting Sample Review
from random import randint
n = randint(1, len(df4))
#n = 3291
print(f"Randomizer ID: {n}\n---------------------------------")

#Pulling up info for sample review
#sample_review = 'this place is dog shit garbage, never coming back fuck this trash'
#actual = 1
#restaurant = 'mcdonalds'
# print(sample_review)
# print(sample_score)
      
      
#Transform random review
review_transformed = cv.transform([sample_review])
      
      
#generating predicted score value      
predicted = nb.predict(review_transformed)[0]

if predicted == actual:
    status = 'Success!!'
else: status = 'Fail'
        
print(f"Restaurant Name: {restaurant}")
print(f"Review Text: {sample_review} \n")
print(f"ML Predicted Yelp Review Score: {predicted}")
print(f"Actual Yelp Review Score: {actual}\n")
print(f"Status: {status}")
# Out:
# Randomizer ID: 38
# ---------------------------------
# Restaurant Name: Lelulos Pizzeria
# Review Text: Best pizza place in plum boro by far!!! The hand spun crust ... sweet sauce.. the garlic butter.. Patyn and Rhiannon are awesome!!!! They go above and BEYOND for their customers!!! Nothing else compares!!!
#
# ML Predicted Yelp Review Score: Positive
# Actual Yelp Review Score: 5
#
# Status: Fail

# %%
#wordcloud module

#have a list of all the reviews for a restaurant
#split it into two dfs: one that has all the 1 star reviews, 1 that has all the 5 star reviews
#make a word cloud of the top words from each DF

# %%
#ML demo module

#web scrape and put all the reviews of the looked-up restaurants in a DF
#run the code above to randomly select one from here

# %%
sample_review = pd.DataFrame({'Data':['this place is garbage, I am never coming back I can promise you that much'],'Review' : [0]  })
sample_review
# Out:
#                                                 Data  Review
# 0  this place is garbage, I am never coming back ...       0

# %%
#applying it

#sample_review = pd.DataFrame({'Data':['this place is garbage, I am never coming back I can promise you that much'],'Review' : [0]  })
sample_review = "Hattie B's has perfected spicy chicken. This was hard for me to admit, as I am from New Orleans and have strong feelings about Louisiana chicken, but nothing that I've had beats Hattie b's. It's even worth the really long wait.you. The variety and quality of the sides is also impressive."

actual = 5;




      
#Transform random review
review_transformed = cv.transform([sample_review])
print(review_transformed)
      
      
#generating predicted score value     
predicted = nb.predict((review_transformed))[0]

if predicted == actual:
    status = 'Success!!'
else: status = 'Fail'
        
print(f"Restaurant Name: {restaurant}")
print(f"Review Text: {sample_review} \n")
print(f"ML Predicted Yelp Review Score: {predicted}")
print(f"Actual Yelp Review Score: {actual}\n")
print(f"Status: {status}")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-3ede7c695d18> in <module>
#      11
#      12 #Transform random review
# ---> 13 review_transformed = cv.transform([sample_review])
#      14 print(review_transformed)
#      15
#
# NameError: name 'cv' is not defined
