# %%
import nltk

# %%
from nl
# Out:
# showing info https://raw.githubusercontent.com/nltk/nltk_data/gh-pages/index.xml

# %%
#Import dependencies
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import numpy as np
import string
import operator
from sklearn.feature_extraction.text import CountVectorizer
import pickle

import nltk
from nltk.corpus import stopwords
nltk.download('stopwords')
from nltk.tokenize import word_tokenize
# Out:
# [nltk_data] Downloading package stopwords to
# [nltk_data]     C:\Users\kledesma\AppData\Roaming\nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!

# %%
import nltk
from nltk.corpus import stopwords
nltk.download('stopwords')
from nltk.tokenize import word_tokenize
# Out:
# [nltk_data] Downloading package stopwords to
# [nltk_data]     C:\Users\kledesma\AppData\Roaming\nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!

# %%
df = pd.read_csv('../../yelp-dataset/yelp_reviews.csv')

# %%
df.head()
# Out:
#               business_id                 name         address       city  \
# 0  pQeaRpvuhoEqudo3uymHIQ  The Empanadas House  404 E Green St  Champaign
# 1  pQeaRpvuhoEqudo3uymHIQ  The Empanadas House  404 E Green St  Champaign
# 2  pQeaRpvuhoEqudo3uymHIQ  The Empanadas House  404 E Green St  Champaign
# 3  pQeaRpvuhoEqudo3uymHIQ  The Empanadas House  404 E Green St  Champaign
# 4  pQeaRpvuhoEqudo3uymHIQ  The Empanadas House  404 E Green St  Champaign
#
#   state postal_code   latitude  longitude  stars  \
# 0    IL       61820  40.110446 -88.233073    4.5
# 1    IL       61820  40.110446 -88.233073    4.5
# 2    IL       61820  40.110446 -88.233073    4.5
# 3    IL       61820  40.110446 -88.233073    4.5
# 4    IL       61820  40.110446 -88.233073    4.5
#
#                                           attributes  \
# 0  {'RestaurantsAttire': "u'casual'", 'Restaurant...
# 1  {'RestaurantsAttire': "u'casual'", 'Restaurant...
# 2  {'RestaurantsAttire': "u'casual'", 'Restaurant...
# 3  {'RestaurantsAttire': "u'casual'", 'Restaurant...
# 4  {'RestaurantsAttire': "u'casual'", 'Restaurant...
#
#                                           categories                 user_id  \
# 0  Ethnic Food, Food Trucks, Specialty Food, Impo...  eSQ3z93DlzkpXK_H6MFEMw
# 1  Ethnic Food, Food Trucks, Specialty Food, Impo...  5So3uZiWDmow4eG8Va0WhQ
# 2  Ethnic Food, Food Trucks, Specialty Food, Impo...  Oh1CPqH5zBZfDEC_2ueTow
# 3  Ethnic Food, Food Trucks, Specialty Food, Impo...  vtqj_61x-cpLjrj1dBQTjQ
# 4  Ethnic Food, Food Trucks, Specialty Food, Impo...  aVWzh3hpLVUSVWSds75Sig
#
#    review_stars                                               text  \
# 0             5  I love the empanadas from the Empanadas House!...
# 1             5  I ordered feta cheese and spinach empanadas an...
# 2             2  I went to the place on Green St today. I went ...
# 3             5  These empanadas are excellent- we are Argentin...
# 4             5  These empanadas are HUGE and in my opinion bet...
#
#                   date
# 0  2013-04-11 18:36:15
# 1  2017-09-21 17:45:53
# 2  2014-10-07 01:07:00
# 3  2013-07-10 18:26:33
# 4  2019-05-07 03:12:10

# %%
df.describe()
# Out:
#            latitude     longitude         stars  review_stars
# count  4.222976e+06  4.222976e+06  4.222976e+06  4.222976e+06
# mean   3.745461e+01 -1.015413e+02  3.761974e+00  3.760848e+00
# std    4.148400e+00  1.624324e+01  6.231684e-01  1.392453e+00
# min    2.149726e+01 -1.580255e+02  1.000000e+00  1.000000e+00
# 25%    3.363615e+01 -1.151529e+02  3.500000e+00  3.000000e+00
# 50%    3.611245e+01 -1.119440e+02  4.000000e+00  4.000000e+00
# 75%    4.110003e+01 -8.084632e+01  4.000000e+00  5.000000e+00
# max    5.129385e+01 -7.280655e+01  5.000000e+00  5.000000e+00

# %%
#Extracting the fields I want
df2 = df[['name', 'city', 'state', 'stars', 'review_stars', 'text', 'date']]
df2.head()
# Out:
#                   name       city state  stars  review_stars  \
# 0  The Empanadas House  Champaign    IL    4.5             5
# 1  The Empanadas House  Champaign    IL    4.5             5
# 2  The Empanadas House  Champaign    IL    4.5             2
# 3  The Empanadas House  Champaign    IL    4.5             5
# 4  The Empanadas House  Champaign    IL    4.5             5
#
#                                                 text                 date
# 0  I love the empanadas from the Empanadas House!...  2013-04-11 18:36:15
# 1  I ordered feta cheese and spinach empanadas an...  2017-09-21 17:45:53
# 2  I went to the place on Green St today. I went ...  2014-10-07 01:07:00
# 3  These empanadas are excellent- we are Argentin...  2013-07-10 18:26:33
# 4  These empanadas are HUGE and in my opinion bet...  2019-05-07 03:12:10

# %%
print(min(df2['date']))
print(max(df2['date']))
print(df2.info())
# Out:
# 2004-10-19 09:07:15
# 2019-12-13 15:50:49
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4222976 entries, 0 to 4222975
# Data columns (total 7 columns):
#  #   Column        Dtype
# ---  ------        -----
#  0   name          object
#  1   city          object
#  2   state         object
#  3   stars         float64
#  4   review_stars  int64
#  5   text          object
#  6   date          object
# dtypes: float64(1), int64(1), object(5)
# memory usage: 225.5+ MB
# None

# %%
#Looking at the rating distribution
sns.countplot(x="review_stars", data = df2)

# %%
df3 = df2[(df2['review_stars'] == 1) | (df2['review_stars'] == 5)]
#df3 = df2[(df2['review_stars'] == 1) | (df2['review_stars'] == 2) | (df2['review_stars'] == 4) | (df2['review_stars'] == 5)]
df3.head()
# Out:
#                   name       city state  stars  review_stars  \
# 0  The Empanadas House  Champaign    IL    4.5             5
# 1  The Empanadas House  Champaign    IL    4.5             5
# 3  The Empanadas House  Champaign    IL    4.5             5
# 4  The Empanadas House  Champaign    IL    4.5             5
# 5      Philthy Phillys     Aurora    ON    4.5             5
#
#                                                 text                 date
# 0  I love the empanadas from the Empanadas House!...  2013-04-11 18:36:15
# 1  I ordered feta cheese and spinach empanadas an...  2017-09-21 17:45:53
# 3  These empanadas are excellent- we are Argentin...  2013-07-10 18:26:33
# 4  These empanadas are HUGE and in my opinion bet...  2019-05-07 03:12:10
# 5  The cheese steak is great here. The guys cooki...  2019-01-26 14:59:53

# %%
#Creating a sentiment value

# %%
#testing out new method
df5 = df2[(df2['review_stars'] == 1) | (df2['review_stars'] == 2) | (df2['review_stars'] == 4) | (df2['review_stars'] == 5)]
df5.head()
# Out:
#                   name       city state  stars  review_stars  \
# 0  The Empanadas House  Champaign    IL    4.5             5
# 1  The Empanadas House  Champaign    IL    4.5             5
# 2  The Empanadas House  Champaign    IL    4.5             2
# 3  The Empanadas House  Champaign    IL    4.5             5
# 4  The Empanadas House  Champaign    IL    4.5             5
#
#                                                 text                 date
# 0  I love the empanadas from the Empanadas House!...  2013-04-11 18:36:15
# 1  I ordered feta cheese and spinach empanadas an...  2017-09-21 17:45:53
# 2  I went to the place on Green St today. I went ...  2014-10-07 01:07:00
# 3  These empanadas are excellent- we are Argentin...  2013-07-10 18:26:33
# 4  These empanadas are HUGE and in my opinion bet...  2019-05-07 03:12:10

# %%
#Creating sentiment value
df5['sentiment'] = np.where(df5['review_stars'] < 3, 'Negative', 'Positive')
df5.head()
# Out:
# C:\Users\kledesma\Anaconda3\lib\site-packages\ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#                   name       city state  stars  review_stars  \
# 0  The Empanadas House  Champaign    IL    4.5             5
# 1  The Empanadas House  Champaign    IL    4.5             5
# 2  The Empanadas House  Champaign    IL    4.5             2
# 3  The Empanadas House  Champaign    IL    4.5             5
# 4  The Empanadas House  Champaign    IL    4.5             5
#
#                                                 text                 date  \
# 0  I love the empanadas from the Empanadas House!...  2013-04-11 18:36:15
# 1  I ordered feta cheese and spinach empanadas an...  2017-09-21 17:45:53
# 2  I went to the place on Green St today. I went ...  2014-10-07 01:07:00
# 3  These empanadas are excellent- we are Argentin...  2013-07-10 18:26:33
# 4  These empanadas are HUGE and in my opinion bet...  2019-05-07 03:12:10
#
#   sentiment
# 0  Positive
# 1  Positive
# 2  Negative
# 3  Positive
# 4  Positive

# %%
df6 = df5[:1000]
df6 = df6.reset_index()

# %%
df6
# Out:
#      index                 name        city state  stars  review_stars  \
# 0        0  The Empanadas House   Champaign    IL    4.5             5
# 1        1  The Empanadas House   Champaign    IL    4.5             5
# 2        2  The Empanadas House   Champaign    IL    4.5             2
# 3        3  The Empanadas House   Champaign    IL    4.5             5
# 4        4  The Empanadas House   Champaign    IL    4.5             5
# ..     ...                  ...         ...   ...    ...           ...
# 995   1186           Sugar Bowl  Scottsdale    AZ    3.5             2
# 996   1187           Sugar Bowl  Scottsdale    AZ    3.5             2
# 997   1188           Sugar Bowl  Scottsdale    AZ    3.5             4
# 998   1189           Sugar Bowl  Scottsdale    AZ    3.5             4
# 999   1190           Sugar Bowl  Scottsdale    AZ    3.5             5
#
#                                                   text                 date  \
# 0    I love the empanadas from the Empanadas House!...  2013-04-11 18:36:15
# 1    I ordered feta cheese and spinach empanadas an...  2017-09-21 17:45:53
# 2    I went to the place on Green St today. I went ...  2014-10-07 01:07:00
# 3    These empanadas are excellent- we are Argentin...  2013-07-10 18:26:33
# 4    These empanadas are HUGE and in my opinion bet...  2019-05-07 03:12:10
# ..                                                 ...                  ...
# 995  While the ice cream was good it didn't make up...  2015-04-01 02:01:41
# 996  The decor is fun, but the ice cream was just w...  2011-06-25 18:38:54
# 997  Stumbled upon this place while walking around ...  2019-03-10 14:21:22
# 998  This place is frozen in time and reminds me of...  2017-06-03 18:26:16
# 999  Sugar Bowl is THE classic Scottsdale spot for ...  2015-11-05 07:52:05
#
#     sentiment
# 0    Positive
# 1    Positive
# 2    Negative
# 3    Positive
# 4    Positive
# ..        ...
# 995  Negative
# 996  Negative
# 997  Positive
# 998  Positive
# 999  Positive
#
# [1000 rows x 9 columns]

# %%
#creating x, y
x = df6['text']
y = df6['sentiment']

# %%
import string
def text_process(text):

    nopunc = [char for char in text if char not in string.punctuation]
    nopunc = ''.join(nopunc)
    
    return [word for word in nopunc.split() if word.lower() not in stopwords.words('english')]

# %%
print(stopwords.words('english'))

sample_text = "Hey there! This is a sample review, which happens to contain punctuations."
processed_text = text_process(sample_text)


print(f"This is the original text: {sample_text}")
print(f"This is the converted text: {processed_text}")
# Out:
# ['i', 'me', 'my', 'myself', 'we', 'our', 'ours', 'ourselves', 'you', "you're", "you've", "you'll", "you'd", 'your', 'yours', 'yourself', 'yourselves', 'he', 'him', 'his', 'himself', 'she', "she's", 'her', 'hers', 'herself', 'it', "it's", 'its', 'itself', 'they', 'them', 'their', 'theirs', 'themselves', 'what', 'which', 'who', 'whom', 'this', 'that', "that'll", 'these', 'those', 'am', 'is', 'are', 'was', 'were', 'be', 'been', 'being', 'have', 'has', 'had', 'having', 'do', 'does', 'did', 'doing', 'a', 'an', 'the', 'and', 'but', 'if', 'or', 'because', 'as', 'until', 'while', 'of', 'at', 'by', 'for', 'with', 'about', 'against', 'between', 'into', 'through', 'during', 'before', 'after', 'above', 'below', 'to', 'from', 'up', 'down', 'in', 'out', 'on', 'off', 'over', 'under', 'again', 'further', 'then', 'once', 'here', 'there', 'when', 'where', 'why', 'how', 'all', 'any', 'both', 'each', 'few', 'more', 'most', 'other', 'some', 'such', 'no', 'nor', 'not', 'only', 'own', 'same', 'so', 'than', 'too', 'very', 's', 't', 'can', 'will', 'just', 'don', "don't", 'should', "should've", 'now', 'd', 'll', 'm', 'o', 're', 've', 'y', 'ain', 'aren', "aren't", 'couldn', "couldn't", 'didn', "didn't", 'doesn', "doesn't", 'hadn', "hadn't", 'hasn', "hasn't", 'haven', "haven't", 'isn', "isn't", 'ma', 'mightn', "mightn't", 'mustn', "mustn't", 'needn', "needn't", 'shan', "shan't", 'shouldn', "shouldn't", 'wasn', "wasn't", 'weren', "weren't", 'won', "won't", 'wouldn', "wouldn't"]
# This is the original text: Hey there! This is a sample review, which happens to contain punctuations.
# This is the converted text: ['Hey', 'sample', 'review', 'happens', 'contain', 'punctuations']

# %%
#Creating the countvectorizor, transforming the data
from sklearn.feature_extraction.text import CountVectorizer

cv = CountVectorizer(analyzer=text_process)   
cv_fit=cv.fit_transform(df6['text'])

#converting into a sparse matrix (will have to repeat for web-scraped data)
X = cv.transform(x)


#Saving vectorizer
pickle.dump(vectorizer, open("vectorizer.pickle", "wb"))

# %%
#Loading Vectorizor
loaded_vectorizor = pickle.load(open("vectorizer.pickle", 'rb'))

# %%
#Splitting data
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=101)

#importing specific ML model, fitting model
from sklearn.naive_bayes import MultinomialNB
model = MultinomialNB()
model.fit(X_train, y_train)

#Saving the model
import pickle
pickle.dump(model, open("model.pickle", 'wb'))

#testing model
predictions = model.predict(X_test)



from sklearn.metrics import confusion_matrix, classification_report
print(confusion_matrix(y_test, predictions))
print('\n')
print(classification_report(y_test, predictions))
# Out:
# [[ 83  28]
#  [ 11 178]]
#
#
#               precision    recall  f1-score   support
#
#     Negative       0.88      0.75      0.81       111
#     Positive       0.86      0.94      0.90       189
#
#     accuracy                           0.87       300
#    macro avg       0.87      0.84      0.86       300
# weighted avg       0.87      0.87      0.87       300

# %%
#Loading the model
loaded_model = pickle.load(open("model.pickle", 'rb'))

result_val = loaded_model.score(X_train, y_train)
result_test = loaded_model.score(X_test, y_test)

print(result_val)
print(result_test)
# Out:
# 0.98
# 0.87

# %%
#Getting Sample Review
from random import randint
n = randint(1, len(df6)-1)
#n = 3291
print(f"Randomizer ID: {n}\n---------------------------------")

#Pulling up info for sample review
sample_review = df6['text'][n]
actual = df6['review_stars'][n]
if actual == 1 | 2:
    actual = 'Negative'
else: actual = 'Positive'
restaurant = df6['name'][n]
# print(sample_review)
# print(sample_score)

#Transform random review
review_transformed = cv.transform([sample_review])
      
      
#generating predicted score value      
predicted = loaded_model.predict(review_transformed)[0]

if predicted == actual:
    status = 'Success!!'
else: status = 'Fail'
        
print(f"Restaurant Name: {restaurant}")
print(f"Review Text: {sample_review} \n")
print(f"ML Predicted Yelp Review Score: {predicted}")
print(f"Actual Yelp Review Score: {actual}\n")
print(f"Status: {status}")
# Out:
# Randomizer ID: 637
# ---------------------------------
# Restaurant Name: Sugar Bowl
# Review Text: Loved the decor and retro vibe here, super cute and stylish. I was impressed by the various sundae options they had available which made it very hard to choose just one to try. I decided on the brownie sundae because as a kid this was my ultimate favorite and the one they offer here did not disappoint. I did have them add hot fudge which it does not usually come with in combination with the marshmallow sauce it does comes with. I have actually never had marshmallows on my sundae before but it was really good! Definitely recommend the brownie sundae!
#
# ML Predicted Yelp Review Score: Positive
# Actual Yelp Review Score: Positive
#
# Status: Success!!

# %%
#Bringing in Jimmy's web scraping code

# %%
#Bringing in Jimmy's web scraping code
web_scrapedf = df5[:1000]
web_scrapedf = web_scrapedf.reset_index()
web_scrapedf
# Out:
#      index                 name        city state  stars  review_stars  \
# 0        0  The Empanadas House   Champaign    IL    4.5             5
# 1        1  The Empanadas House   Champaign    IL    4.5             5
# 2        2  The Empanadas House   Champaign    IL    4.5             2
# 3        3  The Empanadas House   Champaign    IL    4.5             5
# 4        4  The Empanadas House   Champaign    IL    4.5             5
# ..     ...                  ...         ...   ...    ...           ...
# 995   1186           Sugar Bowl  Scottsdale    AZ    3.5             2
# 996   1187           Sugar Bowl  Scottsdale    AZ    3.5             2
# 997   1188           Sugar Bowl  Scottsdale    AZ    3.5             4
# 998   1189           Sugar Bowl  Scottsdale    AZ    3.5             4
# 999   1190           Sugar Bowl  Scottsdale    AZ    3.5             5
#
#                                                   text                 date  \
# 0    I love the empanadas from the Empanadas House!...  2013-04-11 18:36:15
# 1    I ordered feta cheese and spinach empanadas an...  2017-09-21 17:45:53
# 2    I went to the place on Green St today. I went ...  2014-10-07 01:07:00
# 3    These empanadas are excellent- we are Argentin...  2013-07-10 18:26:33
# 4    These empanadas are HUGE and in my opinion bet...  2019-05-07 03:12:10
# ..                                                 ...                  ...
# 995  While the ice cream was good it didn't make up...  2015-04-01 02:01:41
# 996  The decor is fun, but the ice cream was just w...  2011-06-25 18:38:54
# 997  Stumbled upon this place while walking around ...  2019-03-10 14:21:22
# 998  This place is frozen in time and reminds me of...  2017-06-03 18:26:16
# 999  Sugar Bowl is THE classic Scottsdale spot for ...  2015-11-05 07:52:05
#
#     sentiment
# 0    Positive
# 1    Positive
# 2    Negative
# 3    Positive
# 4    Positive
# ..        ...
# 995  Negative
# 996  Negative
# 997  Positive
# 998  Positive
# 999  Positive
#
# [1000 rows x 9 columns]

# %%
#need code here to get jimmy's web-scraped reviews into a list

# %%
web_scrapedf
# Out:
#      index                 name        city state  stars  review_stars  \
# 0        0  The Empanadas House   Champaign    IL    4.5             5
# 1        1  The Empanadas House   Champaign    IL    4.5             5
# 2        2  The Empanadas House   Champaign    IL    4.5             2
# 3        3  The Empanadas House   Champaign    IL    4.5             5
# 4        4  The Empanadas House   Champaign    IL    4.5             5
# ..     ...                  ...         ...   ...    ...           ...
# 995   1186           Sugar Bowl  Scottsdale    AZ    3.5             2
# 996   1187           Sugar Bowl  Scottsdale    AZ    3.5             2
# 997   1188           Sugar Bowl  Scottsdale    AZ    3.5             4
# 998   1189           Sugar Bowl  Scottsdale    AZ    3.5             4
# 999   1190           Sugar Bowl  Scottsdale    AZ    3.5             5
#
#                                                   text                 date  \
# 0    I love the empanadas from the Empanadas House!...  2013-04-11 18:36:15
# 1    I ordered feta cheese and spinach empanadas an...  2017-09-21 17:45:53
# 2    I went to the place on Green St today. I went ...  2014-10-07 01:07:00
# 3    These empanadas are excellent- we are Argentin...  2013-07-10 18:26:33
# 4    These empanadas are HUGE and in my opinion bet...  2019-05-07 03:12:10
# ..                                                 ...                  ...
# 995  While the ice cream was good it didn't make up...  2015-04-01 02:01:41
# 996  The decor is fun, but the ice cream was just w...  2011-06-25 18:38:54
# 997  Stumbled upon this place while walking around ...  2019-03-10 14:21:22
# 998  This place is frozen in time and reminds me of...  2017-06-03 18:26:16
# 999  Sugar Bowl is THE classic Scottsdale spot for ...  2015-11-05 07:52:05
#
#     sentiment
# 0    Positive
# 1    Positive
# 2    Negative
# 3    Positive
# 4    Positive
# ..        ...
# 995  Negative
# 996  Negative
# 997  Positive
# 998  Positive
# 999  Positive
#
# [1000 rows x 9 columns]

# %%
#Looping through the web-scraped reviews to make predictions
for label, row in web_scrapedf.iterrows():
    result = []
    text = row['text']
    #print(text)
    text_transform = cv.transform([text])
    #print(text_transform)[0]
    ml_prediction = loaded_model.predict(text_transform)[0]
    web_scrapedf.at[label, 'ml_predictions'] = ml_prediction

    
web_scrapedf
# Out:
#      index                 name        city state  stars  review_stars  \
# 0        0  The Empanadas House   Champaign    IL    4.5             5
# 1        1  The Empanadas House   Champaign    IL    4.5             5
# 2        2  The Empanadas House   Champaign    IL    4.5             2
# 3        3  The Empanadas House   Champaign    IL    4.5             5
# 4        4  The Empanadas House   Champaign    IL    4.5             5
# ..     ...                  ...         ...   ...    ...           ...
# 995   1186           Sugar Bowl  Scottsdale    AZ    3.5             2
# 996   1187           Sugar Bowl  Scottsdale    AZ    3.5             2
# 997   1188           Sugar Bowl  Scottsdale    AZ    3.5             4
# 998   1189           Sugar Bowl  Scottsdale    AZ    3.5             4
# 999   1190           Sugar Bowl  Scottsdale    AZ    3.5             5
#
#                                                   text                 date  \
# 0    I love the empanadas from the Empanadas House!...  2013-04-11 18:36:15
# 1    I ordered feta cheese and spinach empanadas an...  2017-09-21 17:45:53
# 2    I went to the place on Green St today. I went ...  2014-10-07 01:07:00
# 3    These empanadas are excellent- we are Argentin...  2013-07-10 18:26:33
# 4    These empanadas are HUGE and in my opinion bet...  2019-05-07 03:12:10
# ..                                                 ...                  ...
# 995  While the ice cream was good it didn't make up...  2015-04-01 02:01:41
# 996  The decor is fun, but the ice cream was just w...  2011-06-25 18:38:54
# 997  Stumbled upon this place while walking around ...  2019-03-10 14:21:22
# 998  This place is frozen in time and reminds me of...  2017-06-03 18:26:16
# 999  Sugar Bowl is THE classic Scottsdale spot for ...  2015-11-05 07:52:05
#
#     sentiment ml_predictions
# 0    Positive       Positive
# 1    Positive       Positive
# 2    Negative       Negative
# 3    Positive       Positive
# 4    Positive       Positive
# ..        ...            ...
# 995  Negative       Negative
# 996  Negative       Positive
# 997  Positive       Positive
# 998  Positive       Positive
# 999  Positive       Positive
#
# [1000 rows x 10 columns]

# %%
#Extracting the only two columns we need
scrape_results_df = web_scrapedf[['text', 'ml_predictions']]
print(scrape_results_df)
# Out:
#                                                   text ml_predictions
# 0    I love the empanadas from the Empanadas House!...       Positive
# 1    I ordered feta cheese and spinach empanadas an...       Positive
# 2    I went to the place on Green St today. I went ...       Negative
# 3    These empanadas are excellent- we are Argentin...       Positive
# 4    These empanadas are HUGE and in my opinion bet...       Positive
# ..                                                 ...            ...
# 995  While the ice cream was good it didn't make up...       Negative
# 996  The decor is fun, but the ice cream was just w...       Positive
# 997  Stumbled upon this place while walking around ...       Positive
# 998  This place is frozen in time and reminds me of...       Positive
# 999  Sugar Bowl is THE classic Scottsdale spot for ...       Positive
#
# [1000 rows x 2 columns]

# %%
#Creating list of positive words
positive_wordcloud = scrape_results_df[scrape_results_df['ml_predictions'] == 'Positive']

positivecv = CountVectorizer(analyzer=text_process)   
positive_fit=positivecv.fit_transform(positive_wordcloud['text'])

#creating key value dicitionary pair of counts
positive_word_list = positivecv.get_feature_names();    
positive_count_list = positive_fit.toarray().sum(axis=0)   


positive_words = dict(zip(positive_word_list, positive_count_list))
positive_words = sorted(positive_words.items(), key=operator.itemgetter(1), reverse=True)


positive_words
# Out:
# [('cream', 527),
#  ('ice', 489),
#  ('place', 459),
#  ('good', 341),
#  ('food', 277),
#  ('great', 199),
#  ('like', 183),
#  ('time', 172),
#  ('back', 159),
#  ('service', 156),
#  ('go', 137),
#  ('old', 137),
#  ('get', 135),
#  ('really', 135),
#  ('would', 125),
#  ('always', 122),
#  ('delicious', 122),
#  ('love', 121),
#  ('Sugar', 119),
#  ('little', 118),
#  ('Bowl', 114),
#  ('pho', 109),
#  ('one', 107),
#  ('friendly', 105),
#  ('Scottsdale', 101),
#  ('Ive', 96),
#  ('Im', 95),
#  ('try', 95),
#  ('also', 94),
#  ('menu', 94),
#  ('best', 92),
#  ('got', 91),
#  ('restaurant', 88),
#  ('ordered', 85),
#  ('hot', 82),
#  ('pizza', 79),
#  ('fresh', 78),
#  ('pink', 77),
#  ('family', 73),
#  ('sauce', 73),
#  ('parlor', 72),
#  ('pretty', 72),
#  ('come', 70),
#  ('dont', 70),
#  ('nice', 70),
#  ('people', 70),
#  ('sundae', 70),
#  ('area', 68),
#  ('make', 68),
#  ('cute', 67),
#  ('definitely', 66),
#  ('never', 66),
#  ('order', 64),
#  ('much', 63),
#  ('even', 61),
#  ('around', 59),
#  ('sweet', 59),
#  ('years', 59),
#  ('came', 58),
#  ('eat', 58),
#  ('kids', 58),
#  ('recommend', 57),
#  ('well', 57),
#  ('Mi', 56),
#  ('Vietnamese', 56),
#  ('chocolate', 56),
#  ('right', 56),
#  ('us', 56),
#  ('amazing', 55),
#  ('could', 55),
#  ('going', 55),
#  ('Great', 54),
#  ('Pho', 54),
#  ('better', 54),
#  ('didnt', 54),
#  ('spot', 54),
#  ('think', 54),
#  ('fun', 53),
#  ('town', 53),
#  ('Old', 52),
#  ('super', 52),
#  ('made', 51),
#  ('places', 51),
#  ('take', 51),
#  ('coffee', 50),
#  ('decor', 50),
#  ('busy', 49),
#  ('first', 49),
#  ('lunch', 49),
#  ('soup', 49),
#  ('dessert', 48),
#  ('favorite', 48),
#  ('split', 48),
#  ('breakfast', 47),
#  ('fudge', 47),
#  ('rolls', 47),
#  ('table', 47),
#  ('Thai', 46),
#  ('beef', 46),
#  ('chicken', 46),
#  ('day', 46),
#  ('experience', 46),
#  ('many', 46),
#  ('night', 46),
#  ('Service', 45),
#  ('banana', 45),
#  ('staff', 45),
#  ('want', 45),
#  ('youre', 45),
#  ('feel', 44),
#  ('looking', 44),
#  ('times', 44),
#  ('tried', 44),
#  ('wait', 44),
#  ('went', 44),
#  ('stop', 43),
#  ('sundaes', 43),
#  ('enjoyed', 42),
#  ('every', 42),
#  ('know', 42),
#  ('visit', 42),
#  ('awesome', 41),
#  ('bit', 41),
#  ('perfect', 41),
#  ('spring', 41),
#  ('way', 41),
#  ('worth', 41),
#  ('atmosphere', 40),
#  ('bowl', 40),
#  ('excellent', 40),
#  ('fast', 40),
#  ('2', 39),
#  ('scoop', 39),
#  ('arcade', 38),
#  ('ever', 38),
#  ('sure', 38),
#  ('treat', 38),
#  ('Town', 37),
#  ('clean', 37),
#  ('dishes', 37),
#  ('long', 37),
#  ('say', 37),
#  ('still', 37),
#  ('tasty', 37),
#  ('friends', 36),
#  ('cheese', 35),
#  ('huge', 35),
#  ('loved', 35),
#  ('new', 35),
#  ('since', 35),
#  ('something', 35),
#  ('bad', 34),
#  ('lot', 34),
#  ('price', 34),
#  ('quite', 34),
#  ('two', 34),
#  ('5', 33),
#  ('must', 33),
#  ('rice', 33),
#  ('cant', 32),
#  ('cool', 32),
#  ('enjoy', 32),
#  ('inside', 32),
#  ('probably', 32),
#  ('room', 32),
#  ('sandwich', 32),
#  ('though', 32),
#  ('usually', 32),
#  ('wasnt', 32),
#  ('big', 31),
#  ('classic', 31),
#  ('different', 31),
#  ('fashioned', 31),
#  ('next', 31),
#  ('school', 31),
#  ('Love', 30),
#  ('broth', 30),
#  ('brownie', 30),
#  ('dinner', 30),
#  ('disappointed', 30),
#  ('full', 30),
#  ('last', 30),
#  ('server', 30),
#  ('shop', 30),
#  ('thats', 30),
#  ('4', 29),
#  ('coming', 29),
#  ('home', 29),
#  ('pork', 29),
#  ('quality', 29),
#  ('quick', 29),
#  ('restaurants', 29),
#  ('side', 29),
#  ('soda', 29),
#  ('anything', 28),
#  ('else', 28),
#  ('everything', 28),
#  ('fries', 28),
#  ('stars', 28),
#  ('top', 28),
#  ('authentic', 27),
#  ('enough', 27),
#  ('prices', 27),
#  ('said', 27),
#  ('shrimp', 27),
#  ('special', 27),
#  ('taste', 27),
#  ('actually', 26),
#  ('fish', 26),
#  ('give', 26),
#  ('need', 26),
#  ('small', 26),
#  ('sugar', 26),
#  ('took', 26),
#  ('yummy', 26),
#  ('desserts', 25),
#  ('dish', 25),
#  ('find', 25),
#  ('flavors', 25),
#  ('friend', 25),
#  ('large', 25),
#  ('meat', 25),
#  ('noodle', 25),
#  ('options', 25),
#  ('see', 25),
#  ('thing', 25),
#  ('3', 24),
#  ('Ice', 24),
#  ('butter', 24),
#  ('check', 24),
#  ('chip', 24),
#  ('look', 24),
#  ('meal', 24),
#  ('mint', 24),
#  ('roll', 24),
#  ('shake', 24),
#  ('Food', 23),
#  ('Sunday', 23),
#  ('everyone', 23),
#  ('extra', 23),
#  ('kid', 23),
#  ('minutes', 23),
#  ('portions', 23),
#  ('Family', 22),
#  ('bring', 22),
#  ('counter', 22),
#  ('diner', 22),
#  ('eating', 22),
#  ('flavor', 22),
#  ('found', 22),
#  ('kind', 22),
#  ('pay', 22),
#  ('tables', 22),
#  ('water', 22),
#  ('Definitely', 21),
#  ('Overall', 21),
#  ('almost', 21),
#  ('burger', 21),
#  ('business', 21),
#  ('days', 21),
#  ('however', 21),
#  ('outside', 21),
#  ('packed', 21),
#  ('size', 21),
#  ('treats', 21),
#  ('wonderful', 21),
#  ('50s', 20),
#  ('Cleveland', 20),
#  ('However', 20),
#  ('away', 20),
#  ('chips', 20),
#  ('drive', 20),
#  ('egg', 20),
#  ('husband', 20),
#  ('items', 20),
#  ('sandwiches', 20),
#  ('serve', 20),
#  ('sit', 20),
#  ('things', 20),
#  ('used', 20),
#  ('vermicelli', 20),
#  ('week', 20),
#  ('10', 19),
#  ('Ill', 19),
#  ('absolutely', 19),
#  ('asked', 19),
#  ('bun', 19),
#  ('cold', 19),
#  ('heart', 19),
#  ('local', 19),
#  ('ok', 19),
#  ('reason', 19),
#  ('remember', 19),
#  ('seated', 19),
#  ('vanilla', 19),
#  ('visiting', 19),
#  ('wanted', 19),
#  ('Bell', 18),
#  ('Circus', 18),
#  ('Id', 18),
#  ('Sundae', 18),
#  ('attentive', 18),
#  ('comes', 18),
#  ('customer', 18),
#  ('date', 18),
#  ('doesnt', 18),
#  ('far', 18),
#  ('getting', 18),
#  ('happy', 18),
#  ('isnt', 18),
#  ('location', 18),
#  ('noodles', 18),
#  ('real', 18),
#  ('review', 18),
#  ('tasted', 18),
#  ('theres', 18),
#  ('thought', 18),
#  ('toppings', 18),
#  ('use', 18),
#  ('BBQ', 17),
#  ('One', 17),
#  ('Taco', 17),
#  ('able', 17),
#  ('ago', 17),
#  ('fantastic', 17),
#  ('regular', 17),
#  ('run', 17),
#  ('star', 17),
#  ('waitress', 17),
#  ('walking', 17),
#  ('wrong', 17),
#  ('Cute', 16),
#  ('Really', 16),
#  ('adorable', 16),
#  ('ask', 16),
#  ('cheap', 16),
#  ('especially', 16),
#  ('highly', 16),
#  ('keep', 16),
#  ('liked', 16),
#  ('making', 16),
#  ('malt', 16),
#  ('marshmallow', 16),
#  ('nothing', 16),
#  ('salad', 16),
#  ('style', 16),
#  ('whole', 16),
#  ('Also', 15),
#  ('Came', 15),
#  ('Good', 15),
#  ('Papaya', 15),
#  ('Saturday', 15),
#  ('course', 15),
#  ('fan', 15),
#  ('games', 15),
#  ('grilled', 15),
#  ('hit', 15),
#  ('icecream', 15),
#  ('looked', 15),
#  ('name', 15),
#  ('open', 15),
#  ('plenty', 15),
#  ('reasonable', 15),
#  ('seem', 15),
#  ('seemed', 15),
#  ('theyre', 15),
#  ('truck', 15),
#  ('variety', 15),
#  ('Arizona', 14),
#  ('Best', 14),
#  ('Everything', 14),
#  ('Well', 14),
#  ('Yes', 14),
#  ('birthday', 14),
#  ('bread', 14),
#  ('decent', 14),
#  ('decided', 14),
#  ('generous', 14),
#  ('impressed', 14),
#  ('leave', 14),
#  ('less', 14),
#  ('makes', 14),
#  ('maybe', 14),
#  ('often', 14),
#  ('opened', 14),
#  ('owner', 14),
#  ('priced', 14),
#  ('return', 14),
#  ('reviews', 14),
#  ('selection', 14),
#  ('strawberry', 14),
#  ('surprised', 14),
#  ('toast', 14),
#  ('usual', 14),
#  ('work', 14),
#  ('Cream', 13),
#  ('Nice', 13),
#  ('Scrambler', 13),
#  ('Weve', 13),
#  ('afternoon', 13),
#  ('burgers', 13),
#  ('cash', 13),
#  ('changed', 13),
#  ('choices', 13),
#  ('close', 13),
#  ('cone', 13),
#  ('couple', 13),
#  ('creamy', 13),
#  ('curry', 13),
#  ('fact', 13),
#  ('feeling', 13),
#  ('felt', 13),
#  ('fried', 13),
#  ('glad', 13),
#  ('gone', 13),
#  ('least', 13),
#  ('looks', 13),
#  ('may', 13),
#  ('mom', 13),
#  ('morning', 13),
#  ('part', 13),
#  ('quickly', 13),
#  ('recommended', 13),
#  ('retro', 13),
#  ('sausage', 13),
#  ('scoops', 13),
#  ('seen', 13),
#  ('simple', 13),
#  ('spicy', 13),
#  ('stuff', 13),
#  ('tasting', 13),
#  ('thai', 13),
#  ('trying', 13),
#  ('vibe', 13),
#  ('year', 13),
#  ('youll', 13),
#  ('1', 12),
#  ('Always', 12),
#  ('Banana', 12),
#  ('Brownie', 12),
#  ('Buster', 12),
#  ('Give', 12),
#  ('Petes', 12),
#  ('Strongsville', 12),
#  ('Theres', 12),
#  ('Toronto', 12),
#  ('add', 12),
#  ('amount', 12),
#  ('average', 12),
#  ('avocado', 12),
#  ('booths', 12),
#  ('caramel', 12),
#  ('cartoons', 12),
#  ('cooked', 12),
#  ('eaten', 12),
#  ('game', 12),
#  ('hard', 12),
#  ('heat', 12),
#  ('high', 12),
#  ('lived', 12),
#  ('lots', 12),
#  ('milkshake', 12),
#  ('offer', 12),
#  ('others', 12),
#  ('shops', 12),
#  ('smile', 12),
#  ('walk', 12),
#  ('warm', 12),
#  ('whipped', 12),
#  ('white', 12),
#  ('world', 12),
#  ('young', 12),
#  ('Maries', 11),
#  ('Nothing', 11),
#  ('Super', 11),
#  ('Would', 11),
#  ('ambiance', 11),
#  ('another', 11),
#  ('bar', 11),
#  ('beer', 11),
#  ('cherry', 11),
#  ('city', 11),
#  ('comic', 11),
#  ('crust', 11),
#  ('delivery', 11),
#  ('downtown', 11),
#  ('either', 11),
#  ('end', 11),
#  ('finish', 11),
#  ('front', 11),
#  ('frozen', 11),
#  ('fruit', 11),
#  ('gem', 11),
#  ('hungry', 11),
#  ('interior', 11),
#  ('let', 11),
#  ('meals', 11),
#  ('mean', 11),
#  ('nostalgic', 11),
#  ('okay', 11),
#  ('ordering', 11),
#  ('orders', 11),
#  ('past', 11),
#  ('point', 11),
#  ('put', 11),
#  ('seating', 11),
#  ('served', 11),
#  ('several', 11),
#  ('shakes', 11),
#  ('slow', 11),
#  ('son', 11),
#  ('tell', 11),
#  ('type', 11),
#  ('valley', 11),
#  ('wont', 11),
#  ('yet', 11),
#  ('6', 10),
#  ('Bun', 10),
#  ('Delicious', 10),
#  ('Hingetown', 10),
#  ('Perfect', 10),
#  ('Phoenix', 10),
#  ('Prices', 10),
#  ('Road', 10),
#  ('Wetzels', 10),
#  ('boyfriend', 10),
#  ('brought', 10),
#  ('called', 10),
#  ('choose', 10),
#  ('craving', 10),
#  ('customers', 10),
#  ('desert', 10),
#  ('dining', 10),
#  ('easy', 10),
#  ('entire', 10),
#  ('establishment', 10),
#  ('expected', 10),
#  ('families', 10),
#  ('fancy', 10),
#  ('fashion', 10),
#  ('flavorful', 10),
#  ('garlic', 10),
#  ('half', 10),
#  ('havent', 10),
#  ('history', 10),
#  ('hope', 10),
#  ('mi', 10),
#  ('needed', 10),
#  ('needs', 10),
#  ('nicely', 10),
#  ('oldfashioned', 10),
#  ('omelette', 10),
#  ('owned', 10),
#  ('pecan', 10),
#  ('platter', 10),
#  ('pleasant', 10),
#  ('popular', 10),
#  ('seems', 10),
#  ('servers', 10),
#  ('soon', 10),
#  ('space', 10),
#  ('tea', 10),
#  ('unless', 10),
#  ('veggies', 10),
#  ('wish', 10),
#  ('without', 10),
#  ('1950s', 9),
#  ('7', 9),
#  ('Cant', 9),
#  ('Chinatown', 9),
#  ('Coffee', 9),
#  ('East', 9),
#  ('Excellent', 9),
#  ('Keane', 9),
#  ('Napoli', 9),
#  ('Oh', 9),
#  ('Ordered', 9),
#  ('Since', 9),
#  ('Top', 9),
#  ('Went', 9),
#  ('addition', 9),
#  ('bacon', 9),
#  ('basic', 9),
#  ('care', 9),
#  ('change', 9),
#  ('creams', 9),
#  ('crispy', 9),
#  ('disappoint', 9),
#  ('done', 9),
#  ('ended', 9),
#  ('extremely', 9),
#  ('flavour', 9),
#  ('float', 9),
#  ('gave', 9),
#  ('girl', 9),
#  ('giving', 9),
#  ('goto', 9),
#  ('guys', 9),
#  ('hands', 9),
#  ('late', 9),
#  ('left', 9),
#  ('located', 9),
#  ('mango', 9),
#  ('milk', 9),
#  ('missing', 9),
#  ('money', 9),
#  ('napkins', 9),
#  ('outstanding', 9),
#  ('parlors', 9),
#  ('perfectly', 9),
#  ('potato', 9),
#  ('prepared', 9),
#  ('pretzel', 9),
#  ('second', 9),
#  ('someone', 9),
#  ('sometimes', 9),
#  ('stay', 9),
#  ('stopped', 9),
#  ('sushi', 9),
#  ('sweets', 9),
#  ('syrup', 9),
#  ('takeout', 9),
#  ('thick', 9),
#  ('three', 9),
#  ('totally', 9),
#  ('touch', 9),
#  ('traditional', 9),
#  ('turkey', 9),
#  ('twice', 9),
#  ('typical', 9),
#  ('value', 9),
#  ('waiting', 9),
#  ('walked', 9),
#  ('30', 8),
#  ('Bil', 8),
#  ('Friday', 8),
#  ('Fun', 8),
#  ('Get', 8),
#  ('Hat', 8),
#  ('Loved', 8),
#  ('Mis', 8),
#  ('Scramblers', 8),
#  ('Split', 8),
#  ('Yum', 8),
#  ('across', 8),
#  ('although', 8),
#  ('anyone', 8),
#  ('banh', 8),
#  ('bland', 8),
#  ('brunch', 8),
#  ('businesses', 8),
#  ('call', 8),
#  ('daughter', 8),
#  ('die', 8),
#  ('dirty', 8),
#  ('dry', 8),
#  ('east', 8),
#  ('eggs', 8),
#  ('empanadas', 8),
#  ('enjoying', 8),
#  ('evening', 8),
#  ('filling', 8),
#  ('grab', 8),
#  ('hash', 8),
#  ('hat', 8),
#  ('homemade', 8),
#  ('incredible', 8),
#  ('ingredients', 8),
#  ('instead', 8),
#  ('institution', 8),
#  ('joint', 8),
#  ('kitchen', 8),
#  ('lemon', 8),
#  ('line', 8),
#  ('main', 8),
#  ('mall', 8),
#  ('means', 8),
#  ('mostly', 8),
#  ('pancakes', 8),
#  ('party', 8),
#  ('pick', 8),
#  ('portion', 8),
#  ('pricey', 8),
#  ('problem', 8),
#  ('puff', 8),
#  ('rather', 8),
#  ('ready', 8),
#  ('rich', 8),
#  ('salsa', 8),
#  ('salt', 8),
#  ('serves', 8),
#  ('set', 8),
#  ('sharing', 8),
#  ('smoothie', 8),
#  ('soups', 8),
#  ('spectacular', 8),
#  ('street', 8),
#  ('suggest', 8),
#  ('together', 8),
#  ('tooth', 8),
#  ('tourist', 8),
#  ('unique', 8),
#  ('upon', 8),
#  ('vintage', 8),
#  ('welcome', 8),
#  ('wife', 8),
#  ('working', 8),
#  ('wouldnt', 8),
#  ('60', 7),
#  ('Asian', 7),
#  ('Creek', 7),
#  ('Curry', 7),
#  ('Dont', 7),
#  ('Even', 7),
#  ('First', 7),
#  ('Got', 7),
#  ('Highly', 7),
#  ('Maybe', 7),
#  ('Pad', 7),
#  ('Tenaya', 7),
#  ('added', 7),
#  ('affordable', 7),
#  ('appreciate', 7),
#  ('arent', 7),
#  ('arrived', 7),
#  ('ate', 7),
#  ('base', 7),
#  ('believe', 7),
#  ('cannot', 7),
#  ('carafe', 7),
#  ('celebrate', 7),
#  ('certainly', 7),
#  ('chain', 7),
#  ('children', 7),
#  ('choc', 7),
#  ('choice', 7),
#  ('chose', 7),
#  ('complain', 7),
#  ('complaint', 7),
#  ('concoctions', 7),
#  ('crab', 7),
#  ('cup', 7),
#  ('deliver', 7),
#  ('dipping', 7),
#  ('door', 7),
#  ('drink', 7),
#  ('environment', 7),
#  ('exactly', 7),
#  ('fair', 7),
#  ('favorites', 7),
#  ('floats', 7),
#  ('forward', 7),
#  ('given', 7),
#  ('gross', 7),
#  ('group', 7),
#  ('heard', 7),
#  ('honestly', 7),
#  ('hours', 7),
#  ('issue', 7),
#  ('item', 7),
#  ('job', 7),
#  ('knew', 7),
#  ('lack', 7),
#  ('level', 7),
#  ('live', 7),
#  ('locals', 7),
#  ('locations', 7),
#  ('longer', 7),
#  ('memories', 7),
#  ('might', 7),
#  ('miss', 7),
#  ('months', 7),
#  ('near', 7),
#  ('ones', 7),
#  ('opinion', 7),
#  ('orange', 7),
#  ('oven', 7),
#  ('overall', 7),
#  ('owners', 7),
#  ('peanut', 7),
#  ('perfection', 7),
#  ('person', 7),
#  ('pie', 7),
#  ('plus', 7),
#  ('pop', 7),
#  ('potatoes', 7),
#  ('pretzels', 7),
#  ('rare', 7),
#  ('raspberry', 7),
#  ('realized', 7),
#  ('reasonably', 7),
#  ('shared', 7),
#  ('sign', 7),
#  ('single', 7),
#  ('spend', 7),
#  ('splits', 7),
#  ('spots', 7),
#  ('sticky', 7),
#  ('tired', 7),
#  ('tonight', 7),
#  ('trip', 7),
#  ('true', 7),
#  ('truly', 7),
#  ('visited', 7),
#  ('weekend', 7),
#  ('win', 7),
#  ('window', 7),
#  ('worked', 7),
#  ('20', 6),
#  ('50', 6),
#  ('Atmosphere', 6),
#  ('Chicken', 6),
#  ('English', 6),
#  ('Everyone', 6),
#  ('French', 6),
#  ('Go', 6),
#  ('HUGE', 6),
#  ('Hot', 6),
#  ('Mama', 6),
#  ('Never', 6),
#  ('Next', 6),
#  ('OMG', 6),
#  ('Pizza', 6),
#  ('Plus', 6),
#  ('Quality', 6),
#  ('Staff', 6),
#  ('Tea', 6),
#  ('Thats', 6),
#  ('Thursday', 6),
#  ('anywhere', 6),
#  ('available', 6),
#  ('bbq', 6),
#  ('bet', 6),
#  ('bite', 6),
#  ('blast', 6),
#  ('bomb', 6),
#  ('bowls', 6),
#  ('break', 6),
#  ('brownies', 6),
#  ('cares', 6),
#  ('charm', 6),
#  ('clear', 6),
#  ('comics', 6),
#  ('compared', 6),
#  ('consistent', 6),
#  ('couldnt', 6),
#  ('covered', 6),
#  ('dad', 6),
#  ('deal', 6),
#  ('delivered', 6),
#  ('drinks', 6),
#  ('efficient', 6),
#  ('elsewhere', 6),
#  ('employees', 6),
#  ('etc', 6),
#  ('except', 6),
#  ('fabulous', 6),
#  ('favourite', 6),
#  ('feels', 6),
#  ('filled', 6),
#  ('finished', 6),
#  ('five', 6),
#  ('fix', 6),
#  ('flavourful', 6),
#  ('floor', 6),
#  ('fountain', 6),
#  ('four', 6),
#  ('free', 6),
#  ('gets', 6),
#  ('glass', 6),
#  ('goes', 6),
#  ('gravy', 6),
#  ('green', 6),
#  ('house', 6),
#  ('im', 6),
#  ('impressive', 6),
#  ('inexpensive', 6),
#  ('interesting', 6),
#  ('kept', 6),
#  ('known', 6),
#  ('lady', 6),
#  ('landmark', 6),
#  ('life', 6),
#  ('living', 6),
#  ('lovely', 6),
#  ('loves', 6),
#  ('major', 6),
#  ('melt', 6),
#  ('menus', 6),
#  ('month', 6),
#  ('nights', 6),
#  ('nostalgia', 6),
#  ('noticed', 6),
#  ('oh', 6),
#  ('older', 6),
#  ('original', 6),
#  ('peanuts', 6),
#  ('piece', 6),
#  ('pieces', 6),
#  ('plain', 6),
#  ('play', 6),
#  ('pleasantly', 6),
#  ('pleased', 6),
#  ('red', 6),
#  ('road', 6),
#  ('root', 6),
#  ('salads', 6),
#  ('sat', 6),
#  ('satisfied', 6),
#  ('seafood', 6),
#  ('share', 6),
#  ('short', 6),
#  ('slice', 6),
#  ('slices', 6),
#  ('sorbet', 6),
#  ('speak', 6),
#  ('sprouts', 6),
#  ('standard', 6),
#  ('taco', 6),
#  ('taken', 6),
#  ('tastes', 6),
#  ('thank', 6),
#  ('thee', 6),
#  ('throwback', 6),
#  ('ton', 6),
#  ('topped', 6),
#  ('topping', 6),
#  ('training', 6),
#  ('w', 6),
#  ('waited', 6),
#  ('wall', 6),
#  ('walls', 6),
#  ('weekends', 6),
#  ('whip', 6),
#  ('within', 6),
#  ('wrap', 6),
#  ('write', 6),
#  ('23', 5),
#  ('AZ', 5),
#  ('Boy', 5),
#  ('Come', 5),
#  ('Dusty', 5),
#  ('Dutch', 5),
#  ('Gerrard', 5),
#  ('Grandma', 5),
#  ('Keep', 5),
#  ('LOVE', 5),
#  ('Mango', 5),
#  ('Mimis', 5),
#  ('OK', 5),
#  ('People', 5),
#  ('Probably', 5),
#  ('Shrimp', 5),
#  ('Sundays', 5),
#  ('Thanks', 5),
#  ('Theyre', 5),
#  ('Vegas', 5),
#  ('Yelp', 5),
#  ('agree', 5),
#  ('air', 5),
#  ('along', 5),
#  ('art', 5),
#  ('attached', 5),
#  ('awhile', 5),
#  ('balls', 5),
#  ('barely', 5),
#  ('based', 5),
#  ('basil', 5),
#  ('beat', 5),
#  ('behind', 5),
#  ('beyond', 5),
#  ('bottomless', 5),
#  ('browns', 5),
#  ('camelback', 5),
#  ('cashier', 5),
#  ('cause', 5),
#  ('chairs', 5),
#  ('chance', 5),
#  ('charge', 5),
#  ('chunks', 5),
#  ('combination', 5),
#  ('comfort', 5),
#  ('comfortable', 5),
#  ('comment', 5),
#  ('consistently', 5),
#  ('cookies', 5),
#  ('crumbs', 5),
#  ('cut', 5),
#  ('deep', 5),
#  ('delish', 5),
#  ('dine', 5),
#  ('diners', 5),
#  ('double', 5),
#  ('dough', 5),
#  ('due', 5),
#  ('early', 5),
#  ('everyday', 5),
#  ('exceptional', 5),
#  ('excited', 5),
#  ('expensive', 5),
#  ...]

# %%
#Creating the list of negative words
negative_wordcloud = scrape_results_df[scrape_results_df['ml_predictions'] == 'Negative']

negativecv = CountVectorizer(analyzer=text_process)   
negative_fit=negativecv.fit_transform(negative_wordcloud['text'])

#creating key value dicitionary pair of counts
negative_word_list = negativecv.get_feature_names();    
negative_count_list = negative_fit.toarray().sum(axis=0)   


negative_words = dict(zip(negative_word_list, negative_count_list))
negative_words = sorted(negative_words.items(), key=operator.itemgetter(1), reverse=True)


negative_words
# Out:
# [('food', 277),
#  ('place', 224),
#  ('order', 165),
#  ('like', 145),
#  ('time', 128),
#  ('back', 120),
#  ('fish', 120),
#  ('get', 120),
#  ('go', 118),
#  ('one', 118),
#  ('would', 116),
#  ('good', 108),
#  ('us', 96),
#  ('cream', 94),
#  ('service', 91),
#  ('even', 90),
#  ('ordered', 87),
#  ('dont', 86),
#  ('ice', 82),
#  ('Thai', 79),
#  ('minutes', 78),
#  ('got', 77),
#  ('could', 73),
#  ('never', 72),
#  ('said', 67),
#  ('went', 63),
#  ('didnt', 62),
#  ('sauce', 62),
#  ('ever', 61),
#  ('table', 60),
#  ('restaurant', 59),
#  ('asked', 58),
#  ('came', 57),
#  ('going', 55),
#  ('Im', 54),
#  ('chicken', 54),
#  ('really', 54),
#  ('bad', 53),
#  ('better', 53),
#  ('chips', 53),
#  ('give', 51),
#  ('know', 51),
#  ('people', 51),
#  ('2', 50),
#  ('much', 49),
#  ('shrimp', 49),
#  ('staff', 49),
#  ('Ive', 47),
#  ('location', 47),
#  ('took', 47),
#  ('around', 46),
#  ('told', 46),
#  ('first', 45),
#  ('long', 45),
#  ('say', 43),
#  ('make', 42),
#  ('way', 41),
#  ('great', 39),
#  ('two', 39),
#  ('water', 39),
#  ('experience', 38),
#  ('fried', 38),
#  ('wait', 38),
#  ('menu', 37),
#  ('try', 37),
#  ('dirty', 36),
#  ('drive', 36),
#  ('thought', 36),
#  ('want', 36),
#  ('Sugar', 35),
#  ('customer', 35),
#  ('Bowl', 34),
#  ('made', 34),
#  ('thing', 34),
#  ('think', 34),
#  ('waitress', 34),
#  ('come', 33),
#  ('delivery', 33),
#  ('eat', 33),
#  ('frozen', 33),
#  ('little', 33),
#  ('nothing', 33),
#  ('rude', 33),
#  ('last', 32),
#  ('see', 32),
#  ('someone', 32),
#  ('still', 32),
#  ('3', 31),
#  ('also', 31),
#  ('another', 31),
#  ('curry', 31),
#  ('take', 31),
#  ('times', 31),
#  ('wasnt', 31),
#  ('fries', 30),
#  ('front', 30),
#  ('sandwich', 30),
#  ('terrible', 30),
#  ('ask', 29),
#  ('something', 29),
#  ('stars', 29),
#  ('taste', 29),
#  ('Petes', 28),
#  ('hot', 28),
#  ('next', 28),
#  ('pretty', 28),
#  ('years', 28),
#  ('hard', 27),
#  ('waiting', 27),
#  ('1', 26),
#  ('disappointed', 26),
#  ('flavor', 26),
#  ('since', 26),
#  ('tried', 26),
#  ('well', 26),
#  ('15', 25),
#  ('always', 25),
#  ('cold', 25),
#  ('couldnt', 25),
#  ('left', 25),
#  ('line', 25),
#  ('meal', 25),
#  ('need', 25),
#  ('old', 25),
#  ('reviews', 25),
#  ('thru', 25),
#  ('top', 25),
#  ('waited', 25),
#  ('worst', 25),
#  ('home', 24),
#  ('hour', 24),
#  ('many', 24),
#  ('rice', 24),
#  ('bread', 23),
#  ('called', 23),
#  ('check', 23),
#  ('customers', 23),
#  ('eating', 23),
#  ('fresh', 23),
#  ('guy', 23),
#  ('orders', 23),
#  ('pieces', 23),
#  ('pizza', 23),
#  ('right', 23),
#  ('tasted', 23),
#  ('wanted', 23),
#  ('10', 22),
#  ('20', 22),
#  ('5', 22),
#  ('Food', 22),
#  ('area', 22),
#  ('business', 22),
#  ('day', 22),
#  ('love', 22),
#  ('money', 22),
#  ('put', 22),
#  ('review', 22),
#  ('salad', 22),
#  ('sure', 22),
#  ('4', 21),
#  ('away', 21),
#  ('gave', 21),
#  ('guess', 21),
#  ('half', 21),
#  ('kitchen', 21),
#  ('looked', 21),
#  ('lunch', 21),
#  ('server', 21),
#  ('special', 21),
#  ('used', 21),
#  ('without', 21),
#  ('wont', 21),
#  ('work', 21),
#  ('anything', 20),
#  ('bag', 20),
#  ('beef', 20),
#  ('best', 20),
#  ('bring', 20),
#  ('busy', 20),
#  ('cash', 20),
#  ('door', 20),
#  ('enough', 20),
#  ('horrible', 20),
#  ('least', 20),
#  ('pay', 20),
#  ('reason', 20),
#  ('tell', 20),
#  ('bland', 19),
#  ('call', 19),
#  ('cant', 19),
#  ('care', 19),
#  ('decided', 19),
#  ('dishes', 19),
#  ('else', 19),
#  ('every', 19),
#  ('manager', 19),
#  ('needs', 19),
#  ('nice', 19),
#  ('yet', 19),
#  ('brought', 18),
#  ('cheese', 18),
#  ('coming', 18),
#  ('doesnt', 18),
#  ('fast', 18),
#  ('help', 18),
#  ('instead', 18),
#  ('kids', 18),
#  ('literally', 18),
#  ('look', 18),
#  ('night', 18),
#  ('okay', 18),
#  ('probably', 18),
#  ('ready', 18),
#  ('room', 18),
#  ('sad', 18),
#  ('served', 18),
#  ('walked', 18),
#  ('actually', 17),
#  ('arrived', 17),
#  ('find', 17),
#  ('husband', 17),
#  ('lot', 17),
#  ('noodles', 17),
#  ('open', 17),
#  ('person', 17),
#  ('quality', 17),
#  ('sat', 17),
#  ('store', 17),
#  ('sundae', 17),
#  ('tables', 17),
#  ('today', 17),
#  ('use', 17),
#  ('wrong', 17),
#  ('Scottsdale', 16),
#  ('almost', 16),
#  ('awful', 16),
#  ('car', 16),
#  ('dry', 16),
#  ('family', 16),
#  ('friends', 16),
#  ('greasy', 16),
#  ('kind', 16),
#  ('less', 16),
#  ('paid', 16),
#  ('phone', 16),
#  ('poor', 16),
#  ('prices', 16),
#  ('rolls', 16),
#  ('saw', 16),
#  ('several', 16),
#  ('small', 16),
#  ('though', 16),
#  ('visit', 16),
#  ('worth', 16),
#  ('youre', 16),
#  ('Also', 15),
#  ('Id', 15),
#  ('Ordered', 15),
#  ('Pad', 15),
#  ('clean', 15),
#  ('cooked', 15),
#  ('couple', 15),
#  ('dish', 15),
#  ('getting', 15),
#  ('sitting', 15),
#  ('slow', 15),
#  ('sticky', 15),
#  ('three', 15),
#  ('waiter', 15),
#  ('window', 15),
#  ('Papaya', 14),
#  ('chef', 14),
#  ('different', 14),
#  ('except', 14),
#  ('far', 14),
#  ('fine', 14),
#  ('later', 14),
#  ('ok', 14),
#  ('ordering', 14),
#  ('pad', 14),
#  ('price', 14),
#  ('sorry', 14),
#  ('thats', 14),
#  ('things', 14),
#  ('30', 13),
#  ('However', 13),
#  ('Oh', 13),
#  ('Well', 13),
#  ('Went', 13),
#  ('ate', 13),
#  ('bit', 13),
#  ('breakfast', 13),
#  ('coffee', 13),
#  ('course', 13),
#  ('decor', 13),
#  ('disgusting', 13),
#  ('done', 13),
#  ('eaten', 13),
#  ('everything', 13),
#  ('feel', 13),
#  ('felt', 13),
#  ('finally', 13),
#  ('gross', 13),
#  ('inside', 13),
#  ('let', 13),
#  ('lost', 13),
#  ('meat', 13),
#  ('ones', 13),
#  ('owner', 13),
#  ('real', 13),
#  ('restaurants', 13),
#  ('seemed', 13),
#  ('side', 13),
#  ('spring', 13),
#  ('stuff', 13),
#  ('sweet', 13),
#  ('23', 12),
#  ('50', 12),
#  ('First', 12),
#  ('Ill', 12),
#  ('bacon', 12),
#  ('big', 12),
#  ('breading', 12),
#  ('close', 12),
#  ('driver', 12),
#  ('eggs', 12),
#  ('especially', 12),
#  ('establishment', 12),
#  ('extra', 12),
#  ('extremely', 12),
#  ('fact', 12),
#  ('friendly', 12),
#  ('items', 12),
#  ('lady', 12),
#  ('looking', 12),
#  ('mediocre', 12),
#  ('new', 12),
#  ('places', 12),
#  ('received', 12),
#  ('says', 12),
#  ('second', 12),
#  ('sit', 12),
#  ('started', 12),
#  ('stomach', 12),
#  ('tasteless', 12),
#  ('trying', 12),
#  ('usually', 12),
#  ('warm', 12),
#  ('whole', 12),
#  ('Chicken', 11),
#  ('Dont', 11),
#  ('ago', 11),
#  ('anyone', 11),
#  ('atmosphere', 11),
#  ('bathroom', 11),
#  ('cards', 11),
#  ('cars', 11),
#  ('change', 11),
#  ('charge', 11),
#  ('cleaning', 11),
#  ('egg', 11),
#  ('gets', 11),
#  ('looks', 11),
#  ('mins', 11),
#  ('name', 11),
#  ('past', 11),
#  ('piece', 11),
#  ('run', 11),
#  ('seated', 11),
#  ('soggy', 11),
#  ('star', 11),
#  ('theyre', 11),
#  ('town', 11),
#  ('walk', 11),
#  ('waste', 11),
#  ('white', 11),
#  ('25', 10),
#  ('Old', 10),
#  ('One', 10),
#  ('absolutely', 10),
#  ('asking', 10),
#  ('batter', 10),
#  ('behind', 10),
#  ('bowl', 10),
#  ('burnt', 10),
#  ('cheap', 10),
#  ('closed', 10),
#  ('dining', 10),
#  ('disappointing', 10),
#  ('either', 10),
#  ('fix', 10),
#  ('free', 10),
#  ('game', 10),
#  ('giving', 10),
#  ('high', 10),
#  ('hours', 10),
#  ('large', 10),
#  ('leave', 10),
#  ('maybe', 10),
#  ('mind', 10),
#  ('mouth', 10),
#  ('must', 10),
#  ('near', 10),
#  ('part', 10),
#  ('party', 10),
#  ('pick', 10),
#  ('plate', 10),
#  ('point', 10),
#  ('problem', 10),
#  ('remember', 10),
#  ('sandwiches', 10),
#  ('seems', 10),
#  ('size', 10),
#  ('soup', 10),
#  ('square', 10),
#  ('start', 10),
#  ('stick', 10),
#  ('sticks', 10),
#  ('supposed', 10),
#  ('surprised', 10),
#  ('taking', 10),
#  ('thai', 10),
#  ('wouldnt', 10),
#  ('45', 9),
#  ('6', 9),
#  ('God', 9),
#  ('McDonalds', 9),
#  ('Nothing', 9),
#  ('amount', 9),
#  ('average', 9),
#  ('bill', 9),
#  ('bucks', 9),
#  ('completely', 9),
#  ('correct', 9),
#  ('daughter', 9),
#  ('days', 9),
#  ('decent', 9),
#  ('deep', 9),
#  ('dinner', 9),
#  ('drink', 9),
#  ('end', 9),
#  ('ended', 9),
#  ('excuse', 9),
#  ('expect', 9),
#  ('forgot', 9),
#  ('gone', 9),
#  ('grocery', 9),
#  ('heard', 9),
#  ('hit', 9),
#  ('makes', 9),
#  ('may', 9),
#  ('melt', 9),
#  ('min', 9),
#  ('missing', 9),
#  ('nearly', 9),
#  ('onions', 9),
#  ('placed', 9),
#  ('quick', 9),
#  ('recommend', 9),
#  ('red', 9),
#  ('returning', 9),
#  ('satay', 9),
#  ('sundaes', 9),
#  ('tip', 9),
#  ('understand', 9),
#  ('werent', 9),
#  ('year', 9),
#  ('Fish', 8),
#  ('Groupon', 8),
#  ('Mesa', 8),
#  ('Place', 8),
#  ('Yes', 8),
#  ('already', 8),
#  ('beyond', 8),
#  ('booth', 8),
#  ('bottom', 8),
#  ('boyfriend', 8),
#  ('browns', 8),
#  ('calling', 8),
#  ('cashier', 8),
#  ('comes', 8),
#  ('counter', 8),
#  ('covered', 8),
#  ('damn', 8),
#  ('deal', 8),
#  ('dough', 8),
#  ('excited', 8),
#  ('expensive', 8),
#  ('feeling', 8),
#  ('filthy', 8),
#  ('floor', 8),
#  ('found', 8),
#  ('friend', 8),
#  ('full', 8),
#  ('fun', 8),
#  ('garlic', 8),
#  ('hadnt', 8),
#  ('hate', 8),
#  ('hell', 8),
#  ('hope', 8),
#  ('included', 8),
#  ('isnt', 8),
#  ('keep', 8),
#  ('lacked', 8),
#  ('late', 8),
#  ('longer', 8),
#  ('making', 8),
#  ('meals', 8),
#  ('mention', 8),
#  ('onion', 8),
#  ('parlor', 8),
#  ('patty', 8),
#  ('running', 8),
#  ('salt', 8),
#  ('seen', 8),
#  ('single', 8),
#  ('stop', 8),
#  ('theres', 8),
#  ('thick', 8),
#  ('thinking', 8),
#  ('throw', 8),
#  ('total', 8),
#  ('tough', 8),
#  ('wed', 8),
#  ('week', 8),
#  ('whipped', 8),
#  ('wife', 8),
#  ('working', 8),
#  ('yellow', 8),
#  ('7', 7),
#  ('8', 7),
#  ('American', 7),
#  ('Bell', 7),
#  ('Good', 7),
#  ('Never', 7),
#  ('Really', 7),
#  ('Sweet', 7),
#  ('Town', 7),
#  ('accept', 7),
#  ('arent', 7),
#  ('believe', 7),
#  ('bite', 7),
#  ('card', 7),
#  ('checked', 7),
#  ('combo', 7),
#  ('contact', 7),
#  ('cook', 7),
#  ('cost', 7),
#  ('credit', 7),
#  ('definitely', 7),
#  ('delivered', 7),
#  ('disappointment', 7),
#  ('due', 7),
#  ('entree', 7),
#  ('etc', 7),
#  ('expected', 7),
#  ('favorite', 7),
#  ('finished', 7),
#  ('five', 7),
#  ('four', 7),
#  ('hash', 7),
#  ('however', 7),
#  ('incredibly', 7),
#  ('issue', 7),
#  ('knew', 7),
#  ('lack', 7),
#  ('lettuce', 7),
#  ('man', 7),
#  ('nasty', 7),
#  ('normal', 7),
#  ('noticed', 7),
#  ('number', 7),
#  ('offered', 7),
#  ('oh', 7),
#  ('others', 7),
#  ('overall', 7),
#  ('packed', 7),
#  ('paper', 7),
#  ('pink', 7),
#  ('potato', 7),
#  ('quite', 7),
#  ('rather', 7),
#  ('raw', 7),
#  ('refund', 7),
#  ('rest', 7),
#  ('return', 7),
#  ('save', 7),
#  ('saying', 7),
#  ('seafood', 7),
#  ('seating', 7),
#  ('shame', 7),
#  ('simply', 7),
#  ('slightly', 7),
#  ('spent', 7),
#  ('standing', 7),
#  ('stay', 7),
#  ('sucks', 7),
#  ('sugar', 7),
#  ('super', 7),
#  ('taco', 7),
#  ('takes', 7),
#  ('talking', 7),
#  ('vegetables', 7),
#  ('wants', 7),
#  ('website', 7),
#  ('woman', 7),
#  ('11', 6),
#  ('12', 6),
#  ('Amir', 6),
#  ('Circus', 6),
#  ('Even', 6),
#  ('Family', 6),
#  ('Long', 6),
#  ('People', 6),
#  ('Phoenix', 6),
#  ('Please', 6),
#  ('Tempe', 6),
#  ('Vietnamese', 6),
#  ('able', 6),
#  ('ahead', 6),
#  ('air', 6),
#  ('authentic', 6),
#  ('bar', 6),
#  ('basic', 6),
#  ('bathrooms', 6),
#  ('bought', 6),
#  ('certain', 6),
#  ('certainly', 6),
#  ('chance', 6),
#  ('chili', 6),
#  ('chocolate', 6),
#  ('cilantro', 6),
#  ('craving', 6),
#  ('cute', 6),
#  ('delicious', 6),
#  ('drinks', 6),
#  ('dump', 6),
#  ('easily', 6),
#  ('employees', 6),
#  ('enjoy', 6),
#  ('entire', 6),
#  ('everyone', 6),
#  ('expecting', 6),
#  ('fan', 6),
#  ('flavorless', 6),
#  ('freezer', 6),
#  ('fry', 6),
#  ('girl', 6),
#  ('given', 6),
#  ('happy', 6),
#  ('havent', 6),
#  ('heat', 6),
#  ('higher', 6),
#  ('house', 6),
#  ('immediately', 6),
#  ('including', 6),
#  ('item', 6),
#  ('job', 6),
#  ('ketchup', 6),
#  ('life', 6),
#  ('listen', 6),
#  ('live', 6),
#  ('low', 6),
#  ('mean', 6),
#  ('mentioned', 6),
#  ('menus', 6),
#  ('mess', 6),
#  ('might', 6),
#  ('morning', 6),
#  ('napkins', 6),
#  ('nostalgia', 6),
#  ('obviously', 6),
#  ('online', 6),
#  ('owners', 6),
#  ('pho', 6),
#  ('pickles', 6),
#  ('picture', 6),
#  ('plastic', 6),
#  ('pork', 6),
#  ('portions', 6),
#  ('positive', 6),
#  ('quickly', 6),
#  ('read', 6),
#  ('recently', 6),
#  ('restroom', 6),
#  ('round', 6),
#  ('seat', 6),
#  ('serving', 6),
#  ('shall', 6),
#  ('similar', 6),
#  ('smile', 6),
#  ('somewhat', 6),
#  ('spend', 6),
#  ('stale', 6),
#  ('street', 6),
#  ('talk', 6),
#  ('tea', 6),
#  ('third', 6),
#  ('tiny', 6),
#  ('trash', 6),
#  ('trip', 6),
#  ('tuna', 6),
#  ('turn', 6),
#  ('unfortunately', 6),
#  ('upon', 6),
#  ('wish', 6),
#  ('wonder', 6),
#  ('word', 6),
#  ('worked', 6),
#  ('worse', 6),
#  ('write', 6),
#  ('yes', 6),
#  ('0', 5),
#  ('1st', 5),
#  ('40', 5),
#  ('Awful', 5),
#  ('Bad', 5),
#  ('Came', 5),
#  ('EVER', 5),
#  ('Everything', 5),
#  ('Finally', 5),
#  ('French', 5),
#  ('Fried', 5),
#  ('John', 5),
#  ('Maybe', 5),
#  ('Muffaletta', 5),
#  ('Pete', 5),
#  ('Pizza', 5),
#  ('Plus', 5),
#  ('Silvers', 5),
#  ('Slice', 5),
#  ('Sorry', 5),
#  ('Taco', 5),
#  ('Terrible', 5),
#  ('Upon', 5),
#  ('Weve', 5),
#  ('Worst', 5),
#  ('Yeah', 5),
#  ('Yelp', 5),
#  ('absolute', 5),
#  ('across', 5),
#  ('allow', 5),
#  ('alone', 5),
#  ('answer', 5),
#  ('appeared', 5),
#  ('attention', 5),
#  ('barely', 5),
#  ('beer', 5),
#  ('begin', 5),
#  ('bits', 5),
#  ('brownie', 5),
#  ('canned', 5),
#  ('cannot', 5),
#  ('cause', 5),
#  ('cheeseburger', 5),
#  ('college', 5),
#  ('complained', 5),
#  ('container', 5),
#  ('cool', 5),
#  ('crab', 5),
#  ('crap', 5),
#  ('deliver', 5),
#  ('desserts', 5),
#  ('diner', 5),
#  ('drunken', 5),
#  ('enjoyed', 5),
#  ('entrees', 5),
#  ('eyes', 5),
#  ('fairly', 5),
#  ('figure', 5),
#  ('fit', 5),
#  ('forever', 5),
#  ('games', 5),
#  ('garbage', 5),
#  ('grab', 5),
#  ('grease', 5),
#  ('greeted', 5),
#  ('group', 5),
#  ('hands', 5),
#  ('hear', 5),
#  ('hoping', 5),
#  ('hostess', 5),
#  ('huge', 5),
#  ('idea', 5),
#  ('kid', 5),
#  ('known', 5),
#  ('minute', 5),
#  ('mistake', 5),
#  ('mix', 5),
#  ('needed', 5),
#  ('older', 5),
#  ('opened', 5),
#  ('outside', 5),
#  ('paying', 5),
#  ('petes', 5),
#  ('plain', 5),
#  ('plates', 5),
#  ('play', 5),
#  ('popular', 5),
#  ('potatoes', 5),
#  ('pride', 5),
#  ('problems', 5),
#  ('pull', 5),
#  ('rings', 5),
#  ('root', 5),
#  ('scallops', 5),
#  ('school', 5),
#  ('scoop', 5),
#  ('serve', 5),
#  ('shop', 5),
#  ('short', 5),
#  ('shot', 5),
#  ('show', 5),
#  ('showed', 5),
#  ('shut', 5),
#  ('simple', 5),
#  ('smell', 5),
#  ('soda', 5),
#  ('somewhere', 5),
#  ('son', 5),
#  ('soon', 5),
#  ('sort', 5),
#  ('strange', 5),
#  ('stuck', 5),
#  ('tartar', 5),
#  ('together', 5),
#  ('tokens', 5),
#  ('true', 5),
#  ('truly', 5),
#  ('turkey', 5),
#  ('unless', 5),
#  ('upset', 5),
#  ('veggies', 5),
#  ('walking', 5),
#  ('wall', 5),
#  ('wontons', 5),
#  ('zero', 5),
#  ('27', 4),
#  ('3rd', 4),
#  ('9', 4),
#  ('ALWAYS', 4),
#  ('Chips', 4),
#  ('Didnt', 4),
#  ('Dreyers', 4),
#  ('E', 4),
#  ('Everyone', 4),
#  ('Express', 4),
#  ('Friday', 4),
#  ('Get', 4),
#  ('Glendale', 4),
#  ('Go', 4),
#  ('Grub', 4),
#  ('Hingetown', 4),
#  ('Hub', 4),
#  ('Ice', 4),
#  ('NEVER', 4),
#  ('Okay', 4),
#  ('PM', 4),
#  ('Plastic', 4),
#  ('Probably', 4),
#  ('Reuben', 4),
#  ('Second', 4),
#  ('Seriously', 4),
#  ('Server', 4),
#  ('Service', 4),
#  ('Tea', 4),
#  ('Thats', 4),
#  ('Two', 4),
#  ('Unfortunately', 4),
#  ('Wont', 4),
#  ('acted', 4),
#  ('actual', 4),
#  ('agree', 4),
#  ('allowed', 4),
#  ('angry', 4),
#  ('apart', 4),
#  ('apologetic', 4),
#  ('apology', 4),
#  ('appetizer', 4),
#  ('arrive', 4),
#  ('ashamed', 4),
#  ('assuming', 4),
#  ('avoid', 4),
#  ('backs', 4),
#  ('basically', 4),
#  ('basil', 4),
#  ('battered', 4),
#  ('became', 4),
#  ('bites', 4),
#  ('black', 4),
#  ('bother', 4),
#  ('box', 4),
#  ('broth', 4),
#  ('burger', 4),
#  ('burgers', 4),
#  ('buy', 4),
#  ('chairs', 4),
#  ('cherry', 4),
#  ('chewy', 4),
#  ('childhood', 4),
#  ('chunks', 4),
#  ('claimed', 4),
#  ('clearly', 4),
#  ('clue', 4),
#  ('color', 4),
#  ('crappy', 4),
#  ('crispy', 4),
#  ('crust', 4),
#  ('dairy', 4),
#  ('debit', 4),
#  ('despite', 4),
#  ('dessert', 4),
#  ('dollar', 4),
#  ('doubt', 4),
#  ('downhill', 4),
#  ('downtown', 4),
#  ('driving', 4),
#  ('early', 4),
#  ('edible', 4),
#  ('elsewhere', 4),
#  ('empty', 4),
#  ('ends', 4),
#  ('environment', 4),
#  ('experienced', 4),
#  ('eye', 4),
#  ('face', 4),
#  ('fair', 4),
#  ('favor', 4),
#  ('filets', 4),
#  ('filled', 4),
#  ('forget', 4),
#  ('french', 4),
#  ('fruit', 4),
#  ('fucking', 4),
#  ('general', 4),
#  ('gives', 4),
#  ('gladly', 4),
#  ('glass', 4),
#  ('glasses', 4),
#  ('green', 4),
#  ('grilled', 4),
#  ('groupon', 4),
#  ('guests', 4),
#  ('guys', 4),
#  ('happened', 4),
#  ('hardly', 4),
#  ('heavy', 4),
#  ('homemade', 4),
#  ('hungry', 4),
#  ('iceberg', 4),
#  ('imagine', 4),
#  ('impressed', 4),
#  ('incorrect', 4),
#  ('inedible', 4),
#  ('ingredients', 4),
#  ('joint', 4),
#  ('joke', 4),
#  ('keeping', 4),
#  ('kitsch', 4),
#  ('lacking', 4),
#  ('leaving', 4),
#  ('lets', 4),
#  ('level', 4),
#  ('local', 4),
#  ('lots', 4),
#  ('lousy', 4),
#  ('loved', 4),
#  ('main', 4),
#  ('management', 4),
#  ('mango', 4),
#  ('medium', 4),
#  ('melted', 4),
#  ('men', 4),
#  ('miss', 4),
#  ('mixed', 4),
#  ('mom', 4),
#  ('months', 4),
#  ('mostly', 4),
#  ('mushrooms', 4),
#  ('negative', 4),
#  ('nobody', 4),
#  ('normally', 4),
#  ('notice', 4),
#  ('odd', 4),
#  ('offer', 4),
#  ('opinion', 4),
#  ('ovens', 4),
#  ('overly', 4),
#  ('papaya', 4),
#  ('par', 4),
#  ('pass', 4),
#  ('passed', 4),
#  ('picked', 4),
#  ('pita', 4),
#  ('pleasant', 4),
#  ('please', 4),
#  ('plenty', 4),
#  ('possibly', 4),
#  ('preparation', 4),
#  ('prepared', 4),
#  ...]

# %%
#The end

# %%
df3.review_stars.unique()
# Out:
# array([5, 1], dtype=int64)

# %%
print(df2.shape)
print(df3.shape)
# Out:
# (4222976, 7)
# (2308654, 7)

# %%
df4 = df3[:100]
df4 = df4.reset_index()
df4.head
# Out:
# <bound method NDFrame.head of     index                 name       city state  stars  review_stars  \
# 0       0  The Empanadas House  Champaign    IL    4.5             5
# 1       1  The Empanadas House  Champaign    IL    4.5             5
# 2       3  The Empanadas House  Champaign    IL    4.5             5
# 3       4  The Empanadas House  Champaign    IL    4.5             5
# 4       5      Philthy Phillys     Aurora    ON    4.5             5
# ..    ...                  ...        ...   ...    ...           ...
# 95    155     Mi Mi Restaurant    Toronto    ON    4.0             5
# 96    156     Mi Mi Restaurant    Toronto    ON    4.0             5
# 97    159     Mi Mi Restaurant    Toronto    ON    4.0             5
# 98    167     Mi Mi Restaurant    Toronto    ON    4.0             5
# 99    168     Mi Mi Restaurant    Toronto    ON    4.0             5
#
#                                                  text                 date
# 0   I love the empanadas from the Empanadas House!...  2013-04-11 18:36:15
# 1   I ordered feta cheese and spinach empanadas an...  2017-09-21 17:45:53
# 2   These empanadas are excellent- we are Argentin...  2013-07-10 18:26:33
# 3   These empanadas are HUGE and in my opinion bet...  2019-05-07 03:12:10
# 4   The cheese steak is great here. The guys cooki...  2019-01-26 14:59:53
# ..                                                ...                  ...
# 95  My go-to spot for warm vietnamese treatment in...  2015-08-10 18:09:09
# 96  We dont come here for Pho. We live in Vaughan ...  2016-07-07 20:30:55
# 97  Best BBQ chicken/pork chop rice. When I come h...  2012-12-20 21:22:46
# 98  This was truly great! Every time I'm sick, I N...  2013-07-18 15:04:35
# 99  There is a plethora of Vietnamese places in Ea...  2013-07-24 16:47:41
#
# [100 rows x 8 columns]>

# %%
x = df4['text']
y = df4['review_stars']

# %%
print(x)
# Out:
# 0     I love the empanadas from the Empanadas House!...
# 1     I ordered feta cheese and spinach empanadas an...
# 2     These empanadas are excellent- we are Argentin...
# 3     These empanadas are HUGE and in my opinion bet...
# 4     The cheese steak is great here. The guys cooki...
#                             ...
# 95    My go-to spot for warm vietnamese treatment in...
# 96    We dont come here for Pho. We live in Vaughan ...
# 97    Best BBQ chicken/pork chop rice. When I come h...
# 98    This was truly great! Every time I'm sick, I N...
# 99    There is a plethora of Vietnamese places in Ea...
# Name: text, Length: 100, dtype: object

# %%
pip install string
# Out:
# Note: you may need to restart the kernel to use updated packages.
# ERROR: Could not find a version that satisfies the requirement string (from versions: none)
# ERROR: No matching distribution found for string

# %%
import string
def text_process(text):

    nopunc = [char for char in text if char not in string.punctuation]
    nopunc = ''.join(nopunc)
    
    return [word for word in nopunc.split() if word.lower() not in stopwords.words('english')]

# %%
print(stopwords.words('english'))
# Out:
# ['i', 'me', 'my', 'myself', 'we', 'our', 'ours', 'ourselves', 'you', "you're", "you've", "you'll", "you'd", 'your', 'yours', 'yourself', 'yourselves', 'he', 'him', 'his', 'himself', 'she', "she's", 'her', 'hers', 'herself', 'it', "it's", 'its', 'itself', 'they', 'them', 'their', 'theirs', 'themselves', 'what', 'which', 'who', 'whom', 'this', 'that', "that'll", 'these', 'those', 'am', 'is', 'are', 'was', 'were', 'be', 'been', 'being', 'have', 'has', 'had', 'having', 'do', 'does', 'did', 'doing', 'a', 'an', 'the', 'and', 'but', 'if', 'or', 'because', 'as', 'until', 'while', 'of', 'at', 'by', 'for', 'with', 'about', 'against', 'between', 'into', 'through', 'during', 'before', 'after', 'above', 'below', 'to', 'from', 'up', 'down', 'in', 'out', 'on', 'off', 'over', 'under', 'again', 'further', 'then', 'once', 'here', 'there', 'when', 'where', 'why', 'how', 'all', 'any', 'both', 'each', 'few', 'more', 'most', 'other', 'some', 'such', 'no', 'nor', 'not', 'only', 'own', 'same', 'so', 'than', 'too', 'very', 's', 't', 'can', 'will', 'just', 'don', "don't", 'should', "should've", 'now', 'd', 'll', 'm', 'o', 're', 've', 'y', 'ain', 'aren', "aren't", 'couldn', "couldn't", 'didn', "didn't", 'doesn', "doesn't", 'hadn', "hadn't", 'hasn', "hasn't", 'haven', "haven't", 'isn', "isn't", 'ma', 'mightn', "mightn't", 'mustn', "mustn't", 'needn', "needn't", 'shan', "shan't", 'shouldn', "shouldn't", 'wasn', "wasn't", 'weren', "weren't", 'won', "won't", 'wouldn', "wouldn't"]

# %%
print(stopwords.words('english'))

sample_text = "Hey there! This is a sample review, which happens to contain punctuations."
print(text_process(sample_text))


# print(f"This is the original text: {sample_text}")
# print(f"This is the converted text: {processed_text}")
# Out:
# ['Hey', 'sample', 'review', 'happens', 'contain', 'punctuations']

# %%
#vectorizing, tokenizing data

from sklearn.feature_extraction.text import CountVectorizer

cv = CountVectorizer(analyzer=text_process)   
cv_fit=cv.fit_transform(df4['text'])    


#creating key value dicitionary pair of counts
word_list = cv.get_feature_names();    
count_list = cv_fit.toarray().sum(axis=0)   


final = dict(zip(word_list, count_list))
print(final)

import operator
sorted(final.items(), key=operator.itemgetter(1), reverse=True)

# %%
#vectorizing, tokenizing data

from sklearn.feature_extraction.text import CountVectorizer

cv = CountVectorizer(analyzer=text_process)   
cv_fit=cv.fit_transform(df4['text'])

# %%
#creating key value dicitionary pair of counts
word_list = cv.get_feature_names();    
count_list = cv_fit.toarray().sum(axis=0)   


final = dict(zip(word_list, count_list))
print(final)

# %%
#outdated
bow_transformer = CountVectorizer(analyzer=text_process).fit(x)

# %%
#looking at the words from highest to lowest frequency
import operator
sorted(final.items(), key=operator.itemgetter(1), reverse=True)
# Out:
# [('food', 6451),
#  ('place', 5174),
#  ('good', 3554),
#  ('great', 3389),
#  ('service', 3129),
#  ('time', 2868),
#  ('back', 2756),
#  ('like', 2623),
#  ('get', 2443),
#  ('one', 2259),
#  ('go', 2252),
#  ('restaurant', 2069),
#  ('order', 2022),
#  ('us', 1991),
#  ('would', 1974),
#  ('delicious', 1836),
#  ('ordered', 1722),
#  ('always', 1690),
#  ('really', 1682),
#  ('best', 1681),
#  ('chicken', 1642),
#  ('menu', 1576),
#  ('amazing', 1573),
#  ('try', 1560),
#  ('love', 1559),
#  ('also', 1520),
#  ('got', 1511),
#  ('Ive', 1503),
#  ('even', 1482),
#  ('Im', 1426),
#  ('dont', 1379),
#  ('wait', 1366),
#  ('friendly', 1343),
#  ('come', 1325),
#  ('staff', 1325),
#  ('never', 1245),
#  ('came', 1243),
#  ('well', 1238),
#  ('definitely', 1171),
#  ('eat', 1166),
#  ('recommend', 1159),
#  ('fresh', 1153),
#  ('nice', 1128),
#  ('experience', 1114),
#  ('ever', 1098),
#  ('didnt', 1065),
#  ('make', 1050),
#  ('could', 1038),
#  ('made', 1033),
#  ('pizza', 1030),
#  ('people', 1028),
#  ('first', 1013),
#  ('favorite', 993),
#  ('said', 992),
#  ('table', 970),
#  ('sauce', 958),
#  ('meal', 952),
#  ('much', 931),
#  ('salad', 931),
#  ('went', 924),
#  ('Great', 918),
#  ('going', 897),
#  ('little', 889),
#  ('meat', 887),
#  ('night', 875),
#  ('say', 855),
#  ('know', 843),
#  ('right', 832),
#  ('everything', 826),
#  ('minutes', 823),
#  ('way', 820),
#  ('cheese', 817),
#  ('times', 809),
#  ('dinner', 803),
#  ('want', 801),
#  ('location', 800),
#  ('lunch', 794),
#  ('dishes', 793),
#  ('take', 773),
#  ('every', 770),
#  ('tried', 768),
#  ('hot', 762),
#  ('sure', 755),
#  ('better', 752),
#  ('two', 751),
#  ('vegan', 740),
#  ('2', 734),
#  ('give', 732),
#  ('asked', 721),
#  ('server', 718),
#  ('many', 709),
#  ('cant', 707),
#  ('new', 697),
#  ('beef', 696),
#  ('dish', 675),
#  ('told', 674),
#  ('around', 673),
#  ('customer', 673),
#  ('bar', 668),
#  ('excellent', 665),
#  ('5', 655),
#  ('super', 655),
#  ('took', 655),
#  ('worth', 649),
#  ('cream', 645),
#  ('day', 639),
#  ('ice', 632),
#  ('pork', 632),
#  ('taste', 630),
#  ('soup', 626),
#  ('next', 625),
#  ('think', 622),
#  ('still', 620),
#  ('awesome', 617),
#  ('long', 614),
#  ('spot', 610),
#  ('something', 605),
#  ('area', 603),
#  ('coming', 603),
#  ('Vegas', 600),
#  ('small', 595),
#  ('places', 588),
#  ('bad', 587),
#  ('family', 586),
#  ('fried', 579),
#  ('friends', 578),
#  ('visit', 578),
#  ('drinks', 575),
#  ('since', 574),
#  ('rice', 567),
#  ('flavor', 564),
#  ('home', 561),
#  ('last', 560),
#  ('3', 559),
#  ('perfect', 559),
#  ('manager', 556),
#  ('find', 547),
#  ('side', 545),
#  ('thing', 545),
#  ('atmosphere', 543),
#  ('pretty', 538),
#  ('see', 531),
#  ('pho', 527),
#  ('wasnt', 525),
#  ('different', 524),
#  ('sandwich', 523),
#  ('quality', 520),
#  ('sushi', 517),
#  ('drink', 513),
#  ('lot', 508),
#  ('eating', 507),
#  ('Charlotte', 500),
#  ('restaurants', 496),
#  ('another', 491),
#  ('clean', 491),
#  ('bread', 490),
#  ('spicy', 490),
#  ('shrimp', 488),
#  ('Chinese', 487),
#  ('wanted', 487),
#  ('Food', 486),
#  ('away', 483),
#  ('tea', 482),
#  ('feel', 481),
#  ('top', 480),
#  ('fries', 468),
#  ('happy', 467),
#  ('youre', 467),
#  ('enough', 463),
#  ('disappointed', 462),
#  ('sweet', 460),
#  ('left', 457),
#  ('looking', 456),
#  ('tasty', 452),
#  ('bit', 446),
#  ('husband', 446),
#  ('full', 444),
#  ('special', 442),
#  ('price', 441),
#  ('things', 441),
#  ('big', 440),
#  ('work', 436),
#  ('Everything', 435),
#  ('busy', 434),
#  ('waitress', 431),
#  ('Thai', 429),
#  ('ask', 429),
#  ('tell', 427),
#  ('absolutely', 425),
#  ('fast', 425),
#  ('loved', 425),
#  ('Service', 418),
#  ('10', 417),
#  ('anything', 416),
#  ('tasted', 415),
#  ('years', 412),
#  ('wings', 406),
#  ('Love', 405),
#  ('wonderful', 404),
#  ('must', 403),
#  ('prices', 403),
#  ('cooked', 398),
#  ('town', 398),
#  ('decided', 395),
#  ('large', 394),
#  ('need', 393),
#  ('crispy', 390),
#  ('options', 390),
#  ('fantastic', 389),
#  ('waiting', 384),
#  ('though', 383),
#  ('far', 382),
#  ('friend', 382),
#  ('attentive', 380),
#  ('served', 379),
#  ('fish', 378),
#  ('4', 377),
#  ('gave', 376),
#  ('wont', 372),
#  ('cold', 371),
#  ('hour', 371),
#  ('line', 368),
#  ('tacos', 368),
#  ('else', 365),
#  ('thought', 365),
#  ('tables', 364),
#  ('found', 362),
#  ('owner', 358),
#  ('check', 357),
#  ('put', 356),
#  ('fun', 355),
#  ('kind', 355),
#  ('review', 355),
#  ('business', 354),
#  ('highly', 353),
#  ('dessert', 350),
#  ('enjoyed', 350),
#  ('quick', 349),
#  ('breakfast', 347),
#  ('items', 346),
#  ('everyone', 345),
#  ('wrong', 345),
#  ('vegetarian', 344),
#  ('enjoy', 343),
#  ('look', 343),
#  ('looked', 343),
#  ('wine', 343),
#  ('Italian', 341),
#  ('stars', 341),
#  ('without', 341),
#  ('brought', 337),
#  ('drive', 336),
#  ('week', 334),
#  ('free', 333),
#  ('half', 333),
#  ('rolls', 333),
#  ('almost', 332),
#  ('comes', 331),
#  ('hard', 331),
#  ('inside', 330),
#  ('course', 327),
#  ('thats', 326),
#  ('care', 325),
#  ('least', 325),
#  ('let', 325),
#  ('Ill', 324),
#  ('real', 323),
#  ('dining', 321),
#  ('wife', 321),
#  ('portions', 320),
#  ('seated', 318),
#  ('usually', 318),
#  ('waiter', 318),
#  ('belly', 317),
#  ('customers', 317),
#  ('reviews', 317),
#  ('1', 316),
#  ('huge', 315),
#  ('old', 314),
#  ('Chicken', 313),
#  ('chef', 313),
#  ('getting', 313),
#  ('actually', 308),
#  ('house', 307),
#  ('couldnt', 306),
#  ('Best', 303),
#  ('Definitely', 303),
#  ('One', 303),
#  ('used', 303),
#  ('point', 302),
#  ('open', 301),
#  ('probably', 301),
#  ('burger', 299),
#  ('called', 298),
#  ('today', 297),
#  ('trying', 297),
#  ('ate', 295),
#  ('close', 295),
#  ('Also', 294),
#  ('coffee', 294),
#  ('nothing', 294),
#  ('bring', 293),
#  ('helpful', 291),
#  ('couple', 290),
#  ('extremely', 290),
#  ('makes', 290),
#  ('plate', 289),
#  ('stop', 289),
#  ('walked', 289),
#  ('Veggie', 286),
#  ('hours', 284),
#  ('quite', 284),
#  ('bowl', 282),
#  ('pasta', 282),
#  ('Chef', 280),
#  ('front', 279),
#  ('person', 279),
#  ('pay', 278),
#  ('rude', 277),
#  ('extra', 275),
#  ('done', 273),
#  ('House', 271),
#  ('roll', 271),
#  ('water', 271),
#  ('authentic', 269),
#  ('whole', 269),
#  ('money', 268),
#  ('group', 267),
#  ('orders', 267),
#  ('several', 267),
#  ('chocolate', 266),
#  ('Id', 264),
#  ('ordering', 263),
#  ('party', 263),
#  ('waited', 263),
#  ('sit', 262),
#  ('selection', 261),
#  ('First', 260),
#  ('return', 260),
#  ('egg', 259),
#  ('serve', 259),
#  ('often', 258),
#  ('able', 256),
#  ('curry', 256),
#  ('soon', 256),
#  ('name', 255),
#  ('Soul', 254),
#  ('doesnt', 253),
#  ('noodles', 253),
#  ('ingredients', 252),
#  ('leave', 252),
#  ('second', 252),
#  ('amount', 251),
#  ('beer', 251),
#  ('making', 251),
#  ('guy', 249),
#  ('star', 248),
#  ('later', 247),
#  ('yummy', 247),
#  ('20', 246),
#  ('perfectly', 246),
#  ('outside', 245),
#  ('regular', 245),
#  ('three', 245),
#  ('meals', 244),
#  ('yet', 244),
#  ('especially', 243),
#  ('flavorful', 243),
#  ('sat', 242),
#  ('use', 240),
#  ('finally', 239),
#  ('kids', 239),
#  ('door', 238),
#  ('worst', 237),
#  ('15', 236),
#  ('keep', 235),
#  ('Pho', 234),
#  ('dog', 234),
#  ('end', 234),
#  ('wish', 233),
#  ('flavors', 231),
#  ('date', 230),
#  ('part', 230),
#  ('BBQ', 229),
#  ('eaten', 229),
#  ('Dont', 228),
#  ('style', 228),
#  ('Good', 227),
#  ('arrived', 227),
#  ('high', 227),
#  ('walk', 227),
#  ('instead', 226),
#  ('veggie', 226),
#  ('6', 223),
#  ('impressed', 223),
#  ('started', 222),
#  ('variety', 221),
#  ('cool', 220),
#  ('may', 220),
#  ('Highly', 219),
#  ('ready', 219),
#  ('someone', 219),
#  ('steak', 219),
#  ('bite', 218),
#  ('salads', 217),
#  ('Oh', 216),
#  ('plates', 216),
#  ('reasonable', 216),
#  ('already', 215),
#  ('entire', 215),
#  ('green', 215),
#  ('30', 213),
#  ('believe', 213),
#  ('chips', 213),
#  ('offer', 212),
#  ('room', 211),
#  ('birthday', 210),
#  ('quickly', 210),
#  ('less', 209),
#  ('seating', 209),
#  ('Well', 207),
#  ('kitchen', 207),
#  ('Amazing', 206),
#  ('counter', 206),
#  ('fact', 205),
#  ('appetizer', 204),
#  ('cook', 204),
#  ('felt', 204),
#  ('live', 204),
#  ('ago', 203),
#  ('call', 203),
#  ('eggplant', 203),
#  ('garlic', 203),
#  ('dogs', 202),
#  ('Went', 201),
#  ('boyfriend', 201),
#  ('local', 201),
#  ('recommended', 201),
#  ('saw', 201),
#  ('Las', 200),
#  ('isnt', 200),
#  ('servers', 200),
#  ('size', 200),
#  ('warm', 200),
#  ('Excellent', 199),
#  ('glad', 199),
#  ('prepared', 198),
#  ('bill', 197),
#  ('start', 197),
#  ('portion', 196),
#  ('twice', 196),
#  ('sandwiches', 195),
#  ('store', 195),
#  ('anyone', 193),
#  ('priced', 193),
#  ('employees', 192),
#  ('life', 192),
#  ('working', 192),
#  ('grilled', 191),
#  ('pick', 191),
#  ('tastes', 190),
#  ('havent', 189),
#  ('terrible', 188),
#  ('year', 188),
#  ('fan', 187),
#  ('deal', 186),
#  ('orange', 186),
#  ('reason', 186),
#  ('Really', 185),
#  ('guys', 185),
#  ('unique', 185),
#  ('white', 184),
#  ('either', 182),
#  ('veggies', 182),
#  ('horrible', 181),
#  ('job', 181),
#  ('Korean', 180),
#  ('Overall', 179),
#  ('delivery', 179),
#  ('healthy', 179),
#  ('lady', 179),
#  ('light', 179),
#  ('wouldnt', 179),
#  ('behind', 178),
#  ('expect', 178),
#  ('help', 178),
#  ('literally', 178),
#  ('music', 178),
#  ('meats', 177),
#  ('seemed', 177),
#  ('Vietnamese', 176),
#  ('incredible', 176),
#  ('maybe', 176),
#  ('remember', 176),
#  ('Even', 175),
#  ('add', 175),
#  ('ended', 175),
#  ('Every', 174),
#  ('street', 174),
#  ('together', 173),
#  ('spring', 172),
#  ('decor', 171),
#  ('tip', 171),
#  ('gem', 170),
#  ('man', 170),
#  ('chili', 169),
#  ('choices', 169),
#  ('evening', 169),
#  ('parking', 169),
#  ('Asian', 168),
#  ('Cant', 168),
#  ('choose', 168),
#  ('sitting', 168),
#  ('days', 167),
#  ('favorites', 167),
#  ('broth', 166),
#  ('completely', 166),
#  ('tofu', 166),
#  ('cheap', 165),
#  ('trip', 165),
#  ('However', 164),
#  ('choice', 164),
#  ('greeted', 163),
#  ('games', 162),
#  ('lamb', 162),
#  ('needed', 162),
#  ('phone', 162),
#  ('Thank', 161),
#  ('dirty', 161),
#  ('dry', 161),
#  ('early', 161),
#  ('forward', 161),
#  ('looks', 161),
#  ('opened', 161),
#  ('owners', 161),
#  ('bacon', 160),
#  ('girl', 160),
#  ('mind', 160),
#  ('texture', 160),
#  ('12', 159),
#  ('cooking', 159),
#  ('cute', 159),
#  ('sauces', 159),
#  ('easy', 158),
#  ('plenty', 158),
#  ('saying', 157),
#  ('tender', 157),
#  ('theres', 157),
#  ('theyre', 157),
#  ('Yelp', 156),
#  ('ok', 156),
#  ('stuff', 156),
#  ('truly', 156),
#  ('past', 155),
#  ('received', 155),
#  ('specials', 155),
#  ('fine', 154),
#  ('stopped', 154),
#  ('change', 153),
#  ('gets', 153),
#  ('red', 153),
#  ('youll', 153),
#  ('Never', 152),
#  ('establishment', 152),
#  ('taking', 152),
#  ('Delicious', 151),
#  ('near', 151),
#  ('offered', 151),
#  ('along', 150),
#  ('charge', 150),
#  ('frozen', 149),
#  ('pleasant', 149),
#  ('vegetables', 149),
#  ('Saturday', 148),
#  ('hungry', 148),
#  ('paid', 148),
#  ('soft', 148),
#  ('totally', 148),
#  ('Chili', 147),
#  ('crust', 147),
#  ('decent', 147),
#  ('hostess', 147),
#  ('immediately', 147),
#  ('mouth', 147),
#  ('list', 146),
#  ('burgers', 145),
#  ('world', 145),
#  ('packed', 144),
#  ('pieces', 144),
#  ('empty', 143),
#  ('juice', 143),
#  ('seem', 143),
#  ('share', 143),
#  ('short', 143),
#  ('Kenny', 142),
#  ('dressing', 142),
#  ('gone', 142),
#  ('Would', 141),
#  ('others', 141),
#  ('outstanding', 141),
#  ('Came', 140),
#  ('Sunday', 140),
#  ('Vic', 140),
#  ('across', 140),
#  ('available', 140),
#  ('combo', 140),
#  ('piece', 140),
#  ('thru', 140),
#  ('7', 139),
#  ('cake', 139),
#  ('cocktails', 139),
#  ('excited', 139),
#  ('late', 139),
#  ('liked', 139),
#  ('option', 139),
#  ('run', 139),
#  ('understand', 139),
#  ('added', 138),
#  ('ambiance', 138),
#  ('cannot', 138),
#  ('heard', 138),
#  ('kept', 138),
#  ('needs', 138),
#  ('poor', 138),
#  ('visiting', 138),
#  ('homemade', 137),
#  ('might', 137),
#  ('says', 137),
#  ('sides', 137),
#  ('tasting', 137),
#  ('vibe', 137),
#  ('bartender', 136),
#  ('bland', 136),
#  ('Scottsdale', 135),
#  ('attitude', 135),
#  ('however', 135),
#  ('Beef', 134),
#  ('Ordered', 134),
#  ('giving', 134),
#  ('mean', 133),
#  ('slow', 133),
#  ('tapas', 131),
#  ('treat', 131),
#  ('tuna', 131),
#  ('dip', 130),
#  ('problem', 130),
#  ('stuffed', 130),
#  ('surprised', 130),
#  ('taken', 130),
#  ('8', 129),
#  ('Super', 129),
#  ('knew', 129),
#  ('lots', 129),
#  ('mushrooms', 129),
#  ('Wow', 128),
#  ('game', 128),
#  ('guess', 128),
#  ('show', 128),
#  ('returning', 127),
#  ('Pizza', 126),
#  ('beyond', 126),
#  ('visited', 126),
#  ('AMAZING', 125),
#  ('LOVE', 125),
#  ('card', 125),
#  ('neighborhood', 125),
#  ('patio', 125),
#  ('perfection', 125),
#  ('simple', 125),
#  ('sour', 125),
#  ('welcoming', 125),
#  ('eggs', 124),
#  ('honestly', 124),
#  ('single', 124),
#  ('item', 123),
#  ('lettuce', 123),
#  ('walking', 123),
#  ('Everyone', 122),
#  ('Staff', 122),
#  ('Vegan', 122),
#  ('black', 122),
#  ('burrito', 122),
#  ('etc', 122),
#  ('five', 122),
#  ('hit', 122),
#  ('seems', 122),
#  ('seen', 122),
#  ('based', 121),
#  ('cut', 121),
#  ('die', 121),
#  ('including', 121),
#  ('main', 121),
#  ('ones', 121),
#  ('reservations', 121),
#  ('100', 120),
#  ('Bowl', 120),
#  ('brisket', 120),
#  ('weekend', 120),
#  ('Go', 119),
#  ('generous', 119),
#  ('given', 119),
#  ('management', 119),
#  ('tonight', 119),
#  ('Always', 118),
#  ('chance', 118),
#  ('plus', 118),
#  ('yes', 118),
#  ('appetizers', 117),
#  ('beans', 117),
#  ('exactly', 117),
#  ('hope', 117),
#  ('noodle', 117),
#  ('seafood', 117),
#  ('serving', 117),
#  ('smile', 117),
#  ('toppings', 117),
#  ('disappoint', 116),
#  ('talk', 116),
#  ('type', 116),
#  ('45', 115),
#  ('Absolutely', 115),
#  ('Lupo', 115),
#  ('Nice', 115),
#  ('Pork', 115),
#  ('Toronto', 115),
#  ('covered', 115),
#  ('moved', 115),
#  ('set', 115),
#  ('space', 115),
#  ('thin', 115),
#  ('Try', 114),
#  ('seat', 114),
#  ('son', 114),
#  ('werent', 114),
#  ('Yes', 113),
#  ('delivered', 113),
#  ('desserts', 113),
#  ('glass', 113),
#  ('lobster', 113),
#  ('morning', 113),
#  ('strip', 113),
#  ('finished', 112),
#  ('miss', 112),
#  ('salty', 112),
#  ('simply', 112),
#  ('strawberry', 112),
#  ('Cafe', 111),
#  ('cup', 111),
#  ('environment', 111),
#  ('located', 111),
#  ('bean', 110),
#  ('crazy', 110),
#  ('feeling', 110),
#  ('mins', 110),
#  ('noticed', 110),
#  ('rest', 110),
#  ('window', 110),
#  ('bbq', 109),
#  ('expected', 109),
#  ('min', 109),
#  ('minute', 109),
#  ('month', 109),
#  ('number', 109),
#  ('onions', 109),
#  ('stay', 109),
#  ('talking', 109),
#  ('value', 109),
#  ('brown', 108),
#  ('city', 108),
#  ('cozy', 108),
#  ('daughter', 108),
#  ('expensive', 108),
#  ('fabulous', 108),
#  ('finish', 108),
#  ('mention', 108),
#  ('please', 108),
#  ('seriously', 108),
#  ('shop', 108),
#  ('accommodating', 107),
#  ('anywhere', 107),
#  ('salsa', 107),
#  ('Awesome', 106),
#  ('hands', 106),
#  ('milk', 106),
#  ('salt', 106),
#  ('seasoned', 106),
#  ('sorry', 106),
#  ('New', 105),
#  ('baked', 105),
#  ('floor', 105),
#  ('incredibly', 105),
#  ('traditional', 105),
#  ('due', 104),
#  ('forgot', 104),
#  ('greasy', 104),
#  ('issue', 104),
#  ('phenomenal', 104),
#  ('Zipps', 103),
#  ('awful', 103),
#  ('beautiful', 103),
#  ('longer', 103),
#  ('reservation', 103),
#  ('arent', 102),
#  ('comfortable', 102),
#  ('entrees', 102),
#  ('lovely', 102),
#  ('onion', 102),
#  ('pepper', 102),
#  ('tomato', 102),
#  ('Japanese', 101),
#  ('checked', 101),
#  ('entree', 101),
#  ('forget', 101),
#  ('okay', 101),
#  ('online', 101),
#  ('overall', 101),
#  ('Thanks', 100),
#  ('changed', 100),
#  ('hidden', 100),
#  ('lol', 100),
#  ('mom', 100),
#  ('multiple', 100),
#  ('soda', 100),
#  ('bowls', 99),
#  ('craving', 99),
#  ('duck', 99),
#  ('four', 99),
#  ('knowledgeable', 99),
#  ('recently', 99),
#  ('surprise', 99),
#  ('Friday', 98),
#  ('Thats', 98),
#  ('car', 98),
#  ('chose', 98),
#  ('low', 98),
#  ('months', 98),
#  ('oh', 98),
#  ('play', 98),
#  ('young', 98),
#  ('butter', 97),
#  ('guests', 97),
#  ('leaving', 97),
#  ('rather', 97),
#  ('reasonably', 97),
#  ('salmon', 97),
#  ('satisfied', 97),
#  ('calamari', 96),
#  ('helped', 96),
#  ('mix', 96),
#  ('recommendations', 96),
#  ('shared', 96),
#  ('sometimes', 96),
#  ('broccoli', 95),
#  ('dine', 95),
#  ('expectations', 95),
#  ('explained', 95),
#  ('joint', 95),
#  ('ribs', 95),
#  ('speak', 95),
#  ('split', 95),
#  ('Man', 94),
#  ('Sugar', 94),
#  ('average', 94),
#  ('filling', 94),
#  ('lived', 94),
#  ('although', 93),
#  ('asking', 93),
#  ('cashier', 93),
#  ('level', 93),
#  ('locations', 93),
#  ('pizzas', 93),
#  ('potatoes', 93),
#  ('read', 93),
#  ('soups', 93),
#  ('spinach', 93),
#  ('stand', 93),
#  ('takes', 93),
#  ('waste', 93),
#  ('weve', 93),
#  ('Finally', 92),
#  ('Loved', 92),
#  ('absolute', 92),
#  ('corn', 92),
#  ('head', 92),
#  ('knows', 92),
#  ('rare', 92),
#  ('takeout', 92),
#  ('yelp', 92),
#  ('Mexican', 91),
#  ('app', 91),
#  ('beers', 91),
#  ('cash', 91),
#  ('downtown', 91),
#  ('exceptional', 91),
#  ('filled', 91),
#  ('idea', 91),
#  ('pulled', 91),
#  ('soggy', 91),
#  ('attention', 90),
#  ('closed', 90),
#  ('meatballs', 90),
#  ('n', 90),
#  ('refreshing', 90),
#  ('thai', 90),
#  ('worked', 90),
#  ('Meat', 89),
#  ('alone', 89),
#  ('cafe', 89),
#  ('coconut', 89),
#  ('corner', 89),
#  ('disgusting', 89),
#  ('employee', 89),
#  ('hand', 89),
#  ('kid', 89),
#  ('missing', 89),
#  ('upon', 89),
#  ('de', 88),
#  ('per', 88),
#  ('whatever', 88),
#  ('wrap', 88),
#  ('BEST', 87),
#  ('Fresh', 87),
#  ('Lets', 87),
#  ('Since', 87),
#  ('casual', 87),
#  ('foods', 87),
#  ('turned', 87),
#  ('Spicy', 86),
#  ('basically', 86),
#  ('negative', 86),
#  ('Crispy', 85),
#  ('Friendly', 85),
#  ('box', 85),
#  ('cost', 85),
#  ('face', 85),
#  ('grab', 85),
#  ('happened', 85),
#  ('mushroom', 85),
#  ('potato', 85),
#  ('sign', 85),
#  ('tiny', 85),
#  ('truffle', 85),
#  ('welcome', 85),
#  ('25', 84),
#  ('Fried', 84),
#  ('except', 84),
#  ('girls', 84),
#  ('grill', 84),
#  ('usual', 84),
#  ('watch', 84),
#  ('Get', 83),
#  ('bag', 83),
#  ('charged', 83),
#  ('cuisine', 83),
#  ('favourite', 83),
#  ('goes', 83),
#  ('iced', 83),
#  ('Kung', 82),
#  ('goat', 82),
#  ('hair', 82),
#  ('loud', 82),
#  ('loves', 82),
#  ('menus', 82),
#  ('oil', 82),
#  ('sad', 82),
#  ('true', 82),
#  ('weeks', 82),
#  ('Got', 81),
#  ('Theres', 81),
#  ('addition', 81),
#  ('become', 81),
#  ('class', 81),
#  ('fair', 81),
#  ('hotel', 81),
#  ('obviously', 81),
#  ('questions', 81),
#  ('rich', 81),
#  ('thank', 81),
#  ('thick', 81),
#  ('within', 81),
#  ('Salad', 80),
#  ('Weve', 80),
#  ('brunch', 80),
#  ('crab', 80),
#  ('easily', 80),
#  ('general', 80),
#  ('mixed', 80),
#  ('popular', 80),
#  ('thinking', 80),
#  ('tomatoes', 80),
#  ('treated', 80),
#  ('French', 79),
#  ('Like', 79),
#  ('Seriously', 79),
#  ('ahead', 79),
#  ('bottle', 79),
#  ('chill', 79),
#  ('explain', 79),
#  ('included', 79),
#  ('interesting', 79),
#  ...]

# %%
# Import packages
import matplotlib.pyplot as plt
# %matplotlib inline
# Define a function to plot word cloud
def plot_cloud(wordcloud):
    # Set figure size
    plt.figure(figsize=(40, 30))
    # Display image
    plt.imshow(wordcloud) 
    # No axis details
    plt.axis("off");

# %%
# Import package
from wordcloud import WordCloud, STOPWORDS
# Generate word cloud
wordcloud = WordCloud(width = 3000, height = 1000, random_state=1, background_color='salmon', colormap='Pastel1', collocations=False, stopwords = STOPWORDS).generate_from_frequencies(final)
# Plot
plot_cloud(wordcloud)

# %%
print(STOPWORDS)
# Out:
# {'however', 'other', 'then', 'below', 'through', 'that', "he'll", "it's", 'between', "where's", 'under', 'above', 'been', 'there', 'k', 'we', 'was', 'at', "wouldn't", "they've", 'to', 'for', 'just', "haven't", 'otherwise', 'and', 'having', 'than', 'its', 'her', 'hers', "can't", "hasn't", 'who', "she'll", 'http', 'should', 'yourself', 'because', 'being', "we've", "wasn't", "hadn't", 'on', 'www', 'ours', 'with', 'you', 'your', 'or', "i'm", 'in', "shan't", "couldn't", "isn't", 'did', 'do', 'own', 'be', "let's", 'she', "they'll", 'each', 'would', 'they', 'theirs', 'off', 'i', "here's", "they'd", 'could', 'like', 'both', "i'd", "we're", 'this', 'not', 'have', 'ever', 'r', 'any', "mustn't", 'all', 'has', 'while', 'why', 'me', 'about', 'before', 'but', "you're", 'by', 'few', "he'd", 'had', "shouldn't", 'these', 'same', "she's", 'so', "there's", "they're", 'those', 'an', 'are', "don't", "i'll", 'which', 'until', "you've", 'therefore', 'into', 'am', 'again', 'from', 'if', 'myself', 'it', 'only', 'the', 'over', 'their', 'too', 'of', 'a', 'ought', 'our', "i've", "weren't", "you'd", "when's", 'shall', "won't", 'most', 'doing', 'get', "doesn't", "we'd", 'does', "aren't", 'no', 'how', 'can', "didn't", 'yourselves', 'when', 'more', "what's", 'once', 'itself', 'as', "who's", 'also', "she'd", 'after', 'whom', 'such', 'very', 'cannot', 'his', 'my', 'ourselves', "you'll", 'them', 'else', "he's", 'some', 'nor', 'com', 'himself', 'yours', 'were', 'him', "we'll", 'where', 'during', 'he', "that's", "how's", "why's", 'down', 'is', 'hence', 'against', 'herself', 'further', 'themselves', 'what', 'since', 'here', 'out', 'up'}

# %%
#converting into a sparse matrix (will have to repeat for web-scraped data)
X = cv.transform(x)

# %%
print('Shape of Sparse Matrix: ', X.shape)
print('Amount of Non-Zero occurrences: ', X.nnz)
# Percentage of non-zero values
density = (100.0 * X.nnz / (X.shape[0] * X.shape[1]))
print('Density: {}'.format((density)))
# Out:
# Shape of Sparse Matrix:  (10000, 27438)
# Amount of Non-Zero occurrences:  406349
# Density: 0.14809716451636418

# %%
#Splitting data
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=101)

# %%
#importing specific ML model, fitting model
from sklearn.naive_bayes import MultinomialNB
nb = MultinomialNB()
nb.fit(X_train, y_train)

#testing model
predictions = nb.predict(X_test)

# %%
from sklearn.metrics import confusion_matrix, classification_report
print(confusion_matrix(y_test, predictions))
print('\n')
print(classification_report(y_test, predictions))
# Out:
# [[ 612   69]
#  [  44 2275]]
#
#
#               precision    recall  f1-score   support
#
#            1       0.93      0.90      0.92       681
#            5       0.97      0.98      0.98      2319
#
#     accuracy                           0.96      3000
#    macro avg       0.95      0.94      0.95      3000
# weighted avg       0.96      0.96      0.96      3000

# %%
#Find positive review
positive_review = review[4:5]
print(f" Positive Review Text: {positive_review.text}")
positive_review['text']
# Out:
#  Positive Review Text: 5    The cheese steak is great here. The guys cooki...
# Name: text, dtype: object
# 5    The cheese steak is great here. The guys cooki...
# Name: text, dtype: object

# %%
#Getting Sample Review
from random import randint
n = randint(1, len(df4))
#n = 3291
print(f"Randomizer ID: {n}\n---------------------------------")

#Pulling up info for sample review
sample_review = df4['text'][n]
actual = df4['review_stars'][n]
restaurant = df4['name'][n]
# print(sample_review)
# print(sample_score)
      
      
#Transform random review
review_transformed = cv.transform([sample_review])
      
      
#generating predicted score value      
predicted = nb.predict(review_transformed)[0]

if predicted == actual:
    status = 'Success!!'
else: status = 'Fail'
        
print(f"Restaurant Name: {restaurant}")
print(f"Review Text: {sample_review} \n")
print(f"ML Predicted Yelp Review Score: {predicted}")
print(f"Actual Yelp Review Score: {actual}\n")
print(f"Status: {status}")
# Out:
# Randomizer ID: 38
# ---------------------------------
# Restaurant Name: Amir
# Review Text: 1h15 d'attente pour recevoir mon repas. Le tout était froid et quand j'ai appelé au restaurant ils m'ont racrocher au nez. Ridicule !!
#
# ML Predicted Yelp Review Score: Positive
# Actual Yelp Review Score: 1
#
# Status: Fail

# %%
#Getting Sample Review
from random import randint
n = randint(1, len(df4))
#n = 3291
print(f"Randomizer ID: {n}\n---------------------------------")

#Pulling up info for sample review
#sample_review = 'this place is dog shit garbage, never coming back fuck this trash'
#actual = 1
#restaurant = 'mcdonalds'
# print(sample_review)
# print(sample_score)
      
      
#Transform random review
review_transformed = cv.transform([sample_review])
      
      
#generating predicted score value      
predicted = nb.predict(review_transformed)[0]

if predicted == actual:
    status = 'Success!!'
else: status = 'Fail'
        
print(f"Restaurant Name: {restaurant}")
print(f"Review Text: {sample_review} \n")
print(f"ML Predicted Yelp Review Score: {predicted}")
print(f"Actual Yelp Review Score: {actual}\n")
print(f"Status: {status}")
# Out:
# Randomizer ID: 38
# ---------------------------------
# Restaurant Name: Lelulos Pizzeria
# Review Text: Best pizza place in plum boro by far!!! The hand spun crust ... sweet sauce.. the garlic butter.. Patyn and Rhiannon are awesome!!!! They go above and BEYOND for their customers!!! Nothing else compares!!!
#
# ML Predicted Yelp Review Score: Positive
# Actual Yelp Review Score: 5
#
# Status: Fail

# %%
#wordcloud module

#have a list of all the reviews for a restaurant
#split it into two dfs: one that has all the 1 star reviews, 1 that has all the 5 star reviews
#make a word cloud of the top words from each DF

# %%
#ML demo module

#web scrape and put all the reviews of the looked-up restaurants in a DF
#run the code above to randomly select one from here

# %%
sample_review = pd.DataFrame({'Data':['this place is garbage, I am never coming back I can promise you that much'],'Review' : [0]  })
sample_review
# Out:
#                                                 Data  Review
# 0  this place is garbage, I am never coming back ...       0

# %%
#applying it

#sample_review = pd.DataFrame({'Data':['this place is garbage, I am never coming back I can promise you that much'],'Review' : [0]  })
sample_review = "Hattie B's has perfected spicy chicken. This was hard for me to admit, as I am from New Orleans and have strong feelings about Louisiana chicken, but nothing that I've had beats Hattie b's. It's even worth the really long wait.you. The variety and quality of the sides is also impressive."

actual = 5;




      
#Transform random review
review_transformed = cv.transform([sample_review])
print(review_transformed)
      
      
#generating predicted score value     
predicted = nb.predict((review_transformed))[0]

if predicted == actual:
    status = 'Success!!'
else: status = 'Fail'
        
print(f"Restaurant Name: {restaurant}")
print(f"Review Text: {sample_review} \n")
print(f"ML Predicted Yelp Review Score: {predicted}")
print(f"Actual Yelp Review Score: {actual}\n")
print(f"Status: {status}")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-3ede7c695d18> in <module>
#      11
#      12 #Transform random review
# ---> 13 review_transformed = cv.transform([sample_review])
#      14 print(review_transformed)
#      15
#
# NameError: name 'cv' is not defined
